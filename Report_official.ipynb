# %% [markdown]
# # Introduction
#
# This project will be a wide example of usage of NLP and sentiment analysis with the Twitter 1.6 million tweets dataset that involves analyzing a large collection of tweets to understand the sentiments of the users on different topics. The project aims to use natural language processing techniques to process, clean, and analyze the text data to gain insights into the sentiment expressed by users.
#
#
#
#
# ### Natural Language Processing (NLP)
#
# Natural Language Processing (NLP) Is a field of computer science that deals with the interaction between computers and human language. It involves developing algorithms and computational models that enable computers to understand, interpret, and generate human language.
#
# NLP involves a wide range of techniques and technologies, including machine learning, deep learning, and linguistics. Some of the key tasks in NLP include:
#
# 1. **Text classification:** Assigning categories or labels to text data based on its content.
# 2. **Sentiment analysis:** Analyzing the tone or emotion in a piece of text.
# 3. **Named entity recognition:** Identifying and extracting specific entities such as people, organizations, and locations from text data.
# 4. **Part-of-speech tagging:** Labeling the parts of speech (noun, verb, adjective, etc.) in a sentence.
# 5. **Machine translation:** Translating text from one language to another.
# NLP has a wide range of practical applications, including chatbots, virtual assistants, language translation software, and text analytics tools for business intelligence.
#
# In recent years, there has been a surge of interest in NLP due to the availability of large amounts of textual data, advancements in machine learning and deep learning, and the increasing importance of natural language interfaces in various industries.
#
# Overall, NLP is an exciting and rapidly evolving field that has the potential to transform the way we interact with computers and each other through language.
#
#
#
#
#
# ### Sentiment Analysis
#
# Sentiment Analysis is one of the most popular applications of NLP. It involves the use of natural language processing, text analysis, and computational linguistics to identify and extract subjective information from text data. Sentiment analysis aims to determine the emotional tone, attitudes, and opinions expressed in a piece of text, whether it's positive, negative, or neutral. The analysis can be done at the document, sentence, or aspect level.
#
# Sentiment analysis has numerous applications, such as customer feedback analysis, brand reputation management, market research, and political analysis. It is used by companies to analyze customer reviews, social media posts, and survey responses to improve their products and services. In political analysis, sentiment analysis is used to predict the outcome of elections by analyzing the sentiment of the voters towards the candidates. Sentiment analysis can also be used to monitor social media for public opinion on various issues, such as climate change, public health, and social justice.
#
# There are several methods used in sentiment analysis, including rule-based systems, machine learning, and deep learning. Rule-based systems involve the use of pre-defined rules to classify text into positive, negative, or neutral. Machine learning involves the use of algorithms to learn from data and classify text into sentiments. Deep learning involves the use of artificial neural networks to learn from data and classify text into sentiments. The choice of method depends on the complexity of the data and the accuracy required for the analysis.

# %% [markdown]
# # The Dataset
#
# The Sentiment140 dataset is an excellent resource for those interested in performing sentiment analysis of Twitter data. It contains 1.6 million tweets pre-classified as either positive or negative. This dataset is well suited to machine learning approaches as it contains a large number of easily accessible features, such as tweet text, user profile information, and sentiment. The challenge associated with this dataset is that the tweets can be full of slang, abbreviations, and other language features that are difficult for machines to interpret.
#
# You can find the dataset in the Kaggle link here: [Sentiment140](https://www.kaggle.com/datasets/kazanova/sentiment140)
#
#
#
# Each tweet in the dataset has several features, including the following:
#
# **target:** the polarity of the tweet (0 = negative, 4 = positive)
#
# **ids:** The id of the tweet (eg: 2087)
#
# **date:** the date of the tweet (eg: Sat May 16 23:58:44 UTC 2009)
#
# **flag:** The query (lyx). If there is no query, then this value is NO_QUERY.
#
# **user:** the user that tweeted (eg: robotickilldozr)
#
# **text:** the text of the tweet (Leg: yx is cool)
#
#
# We will use supervised and unsupervised learning methods to evaluate this dataset based on various machine learning theories. In particular, we will explore how well these models can predict the sentiment label of each tweet based on its text. We will also examine various NLP techniques that can be used to preprocess the text data and improve the performance of our models.
#
# Overall, this dataset provides an excellent opportunity to explore the application of NLP methods to real-world data. By analyzing this data, we can gain insights into how people express sentiment on social media and develop models that can accurately classify the sentiment of new tweets.

# %% [markdown]
# ## Exploratory Analysis
#
# Exploratory analysis is a process of analyzing and summarizing data to gain an initial understanding of the dataset. In the context of a report about the Twitter 1.6 million tweets dataset, exploratory analysis would involve examining the data to uncover patterns, trends, and insights that can help answer research questions or hypotheses.
#
# It can provide valuable insights into the topics, trends, and patterns of usage on Twitter. This analysis can be used to guide further research or inform business decisions related to social media marketing or audience engagement.

# %% [markdown]
# ### Importing the dataset
#
#  This code below imports all the necessary libraries and dependencies for a Natural Language Processing (NLP) project.

# %%
# Import the Necessary Dependencies

# Data Manipulation
import re ## Import regular expression operator for manipulating text
import numpy as np ## Import numpy for numerical manipulation
import pandas as pd ## Import pandas for data manipulation
import string ## Import string for string manipulation

# plotting
import seaborn as sns ## Import seaborn for visualization
from wordcloud import WordCloud ## Import WordCloud for visualization of wordclouds
import matplotlib.pyplot as plt ## Import matplotlib for visualization
import plotly.express as px ## Import plotly for visualization

# Methods and stopwords text processing
import nltk ## Import nltk for natural language processing
from nltk.stem import WordNetLemmatizer ## Import WordNetLemmatizer from nltk for lemmatization
from nltk.corpus import stopwords ## Import stopwords from nltk for removing stop words
from nltk.tokenize import word_tokenize ## Import word_tokenize from nltk for tokenizing text
from nltk.stem import WordNetLemmatizer ## Import WordNetLemmatizer from nltk for lemmatization
from sklearn.model_selection import train_test_split ## Import train_test_split from sklearn for splitting data into train and test sets
from sklearn.feature_extraction.text import TfidfVectorizer ## Import TfidfVectorizer from sklearn for transforming text into numerical representations
from nltk.tokenize import RegexpTokenizer ## Import RegexpTokenizer from nltk for tokenizing text
from collections import Counter ## Import Counter from collections for counting elements in a list
from nltk.stem import PorterStemmer ## Import PorterStemmer from nltk for stemming text

# Machine Learning Libraries
from sklearn.svm import LinearSVC ## Import LinearSVC from sklearn for SVM classification
from sklearn.naive_bayes import BernoulliNB ## Import BernoulliNB from sklearn for Naive Bayes classification
from sklearn.linear_model import LogisticRegression ## Import LogisticRegression from sklearn for logistic regression classification
from sklearn.metrics import confusion_matrix, classification_report ## Import confusion_matrix and classification_report from sklearn for performance evaluation
from sklearn.metrics import accuracy_score ## Import accuracy_score from sklearn for calculating accuracy
from sklearn.utils import resample ## Import resample from sklearn for resampling data
from sklearn.model_selection import train_test_split ## Import train_test_split from sklearn for splitting data into train and test sets
from sklearn.tree import DecisionTreeClassifier ## Import DecisionTreeClassifier from sklearn for decision tree classification
from sklearn.ensemble import RandomForestClassifier ## Import RandomForestClassifier from sklearn for random forest classification
import xgboost as xgb ## Import xgboost for XGBoost classification
from sklearn.neighbors import KNeighborsClassifier ## Import KNeighborsClassifier from sklearn for k-nearest neighbors classification
from sklearn import metrics, pipeline, decomposition, feature_extraction,linear_model, model_selection, preprocessing ## Import several modules from sklearn for machine learning preprocessing and pipelines
from sklearn.linear_model import RidgeClassifier ## Import RidgeClassifier from sklearn for ridge classification
from sklearn.naive_bayes import GaussianNB ## Import GaussianNB from sklearn for Naive Bayes classification

import keras ## Import keras for deep learning
from keras.models import Sequential, Model ## Import Sequential and Model from keras for deep learning models
from keras import layers ## Import layers from keras for deep learning layers
from keras.layers import Dense, Dropout, Input, Embedding ## Import Dense, Dropout, Input, and Embedding from keras for deep learning layers

# %% [markdown]
# Lets import the dataset in CSV format that contains Twitter data, and performing some data cleaning and preprocessing operations on it.
#
# In addition, the 'text' column is the most important feature for an NLP project that involves analyzing and classifying tweets. Therefore, keeping only the 'target' and 'text' columns is a good choice to focus the analysis on the most relevant information for the project.

# %%
# Importing the dataset and defining column names
DATASET_COLUMNS=['target','ids','date','flag','user','text']

# Defining the dataset encoding
DATASET_ENCODING = "ISO-8859-1"

# Reading the CSV file into a pandas DataFrame
df_raw = pd.read_csv('twitter_data.csv', encoding=DATASET_ENCODING, names=DATASET_COLUMNS)

# Printing the first five rows of the DataFrame to explore the data
df_raw.head()

# Keeping only the 'target' and 'text' columns in the DataFrame
df_raw = df_raw[['target','text']]

# Replacing the value 4 with 1 in the 'target' column of the DataFrame to ease understanding
df_raw['target'] = df_raw['target'].replace(4,1)

# Creating lists for the 'text' and 'target' columns
text, target = list(df_raw['text']), list(df_raw['target'])

# %% [markdown]
# In an NLP project, the size of the dataset can impact the quality of the models and the accuracy of the results. If the dataset is too small, the models may not be able to capture the complexity of the language, leading to underfitting and poor performance. On the other hand, if the dataset is too large, it may require more time and computational resources to process, and may increase the risk of overfitting, which occurs when the model becomes too complex and fits the training data too well, but performs poorly on new data.
#
# Therefore, knowing the size of the dataset is important for making informed decisions about how much data to use for training and evaluation, and for optimizing the performance of the models.

# %%
# Print the dataset size

print('length of data is', len(df_raw))
# Out:
# length of data is 1600000

# %% [markdown]
# ### Optimizing the dataset
#
# Reducing the dataset size is important for NLP projects because it can help to improve the efficiency of the data processing and modeling phases. Processing large datasets can be computationally intensive and time-consuming, and may require specialized hardware or cloud computing resources. Reducing the dataset size can also help to improve the quality of the models by reducing the risk of overfitting, which can occur when models are trained on too much data.
#
# Overall, the code above is an essential step for preparing the dataset for an NLP project, and reducing the size of the dataset while keeping the most relevant columns can help to improve the efficiency and quality of the analysis.

# %%
# Create subgroups based on the target column
subgroups = df_raw['target'].astype(str)  # Convert the 'target' column to a string to ensure correct stratification

# Specify the number of tweets you want to include in your final dataset for each subgroup
n_samples = 20000  # Replace with the desired number of tweets in each subgroup

# Use train_test_split to do stratified sampling
target0_df, _ = train_test_split(df_raw[subgroups == '0'], stratify=subgroups[subgroups == '0'], train_size=n_samples/len(df_raw[subgroups == '0']), random_state=42)
target1_df, _ = train_test_split(df_raw[subgroups == '1'], stratify=subgroups[subgroups == '1'], train_size=n_samples/len(df_raw[subgroups == '1']), random_state=42)

# Combine the two subgroups into a single dataframe
df = pd.concat([target0_df, target1_df], ignore_index=True)

# Save the sampled dataset
df.to_csv('sampled_twitter_data.csv', index=False)

# %% [markdown]
# ### Checking the current dataset
#
# There are several reasons why it is important to perform the exploratory data analysis and check the type of data, summary statistics, unique values, and null values, specifically:
#
# **Check the data types:** It is essential to check the data types of each variable or column in the dataset, as it determines the type of analysis that can be performed on the data. For example, NLP projects often deal with text data, which requires different preprocessing techniques and modeling approaches than numerical or categorical data. If the data types are incorrect, it can lead to incorrect conclusions and poor modeling results.
#
# **Summary statistics:** Checking summary statistics such as mean, median, standard deviation, and quartiles can provide insight into the distribution and spread of the data. This information can help in detecting outliers, identifying potential data quality issues, and deciding on appropriate data preprocessing steps. For example, if the mean and median are significantly different, it may suggest that the data is skewed and may require normalization.
#
# **Unique values:** Checking the unique values of each column can reveal the cardinality and variability of the data, and identify potential issues such as misspellings, duplicates, or inconsistent formatting. In NLP projects, unique values can help in detecting special characters, emojis, or other text patterns that may require special handling or preprocessing.
#
# **Null values:** Checking for null or missing values is important to ensure the completeness and integrity of the data, and to decide on appropriate handling strategies such as imputation or deletion. In NLP projects, missing values can occur in text data due to incomplete sentences, missing words, or typos, and may require special handling to avoid errors or biases in the analysis.
#
# In summary, exploratory data analysis and checking the type of data, summary statistics, unique values, and null values are critical steps in any data analysis project, including NLP projects. They provide valuable insights into the characteristics and quality of the data, and help in making informed decisions about preprocessing, modeling, and evaluation steps.

# %%
# Print the lenght of the dataset
print('The new length of data is', len(df))
# Out:
# The new length of data is 40000

# %%
# Display the concise summary of the DataFrame

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40000 entries, 0 to 39999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   target  40000 non-null  int64
#  1   text    40000 non-null  object
# dtypes: int64(1), object(1)
# memory usage: 625.1+ KB

# %%
# Checking the data type of each column in the DataFrame

df.dtypes
# Out:
# target     int64
# text      object
# dtype: object

# %%
# Checking for null values

np.sum(df.isnull().any(axis=1))
# Out:
# 0

# %%
# Rows and columns in the dataset

print('Count of columns in the data is:  ', len(df.columns))
print('Count of rows in the data is:  ', len(df))
# Out:
# Count of columns in the data is:   2
# Count of rows in the data is:   40000

# %%
# Check unique target values

df['target'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
# Check the number of target values

df['target'].nunique()
# Out:
# 2

# %% [markdown]
# ### Visualize the current dataset
#
# We will now proceed with a more comprehensive exploratory analysis, incorporating data visualization techniques to generate graphical representations of the dataset. This will facilitate a broader understanding of the data, aiding in the identification of patterns and trends that may not be immediately apparent through other means of analysis.

# %%
# Data Visualization of Target Variables

# Plotting the distribution for dataset.
ax = df.groupby('target').count().plot(kind='bar', title='Distribution of data',legend=False)
ax.set_xticklabels(['Negative','Positive'], rotation=0)

# Storing data in lists.
text, target = list(df['text']), list(df['target'])

# %%
# Frequency of each unique value in the "target" column of the dataframe 
sns.countplot(x='target', data=df)
# Out:
# <Axes: xlabel='target', ylabel='count'>

# %% [markdown]
# ### First read at our text data
#
# In a NLP project it is important to check the first and last rows of the text column using the codes provided, as it provides an initial understanding of the nature and quality of the data.
#
# Firstly, the tweets on Twitter are typically limited to 280 characters, and users may use abbreviations, emojis, and other non-standard language. Thus, the first few rows of the text column may contain some examples of these non-standard language usages. By analyzing these examples, NLP analysts can gain insight into the type of language used on Twitter and determine if any special preprocessing steps are needed.
#
# Secondly, Twitter is known for its diverse user base, and the tweets' content can vary significantly in terms of topic, sentiment, and tone. By checking the first few rows of the text column, analysts can get a general idea of the data's nature and see if the tweets align with their research objectives. This information can help guide the selection of appropriate NLP techniques, such as sentiment analysis or topic modeling.
#
# Thirdly, checking the last rows of the text column can help detect potential issues, such as truncated or missing tweets. This is particularly important in large datasets such as Twitter 1.6 million tweets, where manual inspection of the data is impractical. By ensuring that the dataset is complete and free of truncation, analysts can be confident that their analysis results are reliable and accurate.

# %%
# Checking the first rows of text column

df['text'].head()
# Out:
# 0                    @streetkingpin  wish I was there!
# 1                                   I don't feel good
# 2    my mom was just asking if i could work w/her o...
# 3    Just arrived home and kaki gw pegeeeellll  htt...
# 4    @saudarilee It was a pleasure &quot;babysittin...
# Name: text, dtype: object

# %%
# Checking the last rows of text column

df['text'].tail()
# Out:
# 39995    @Dan_Jones there is always something to be pay...
# 39996    a cool day on the bay today, light winds and a...
# 39997    Voting is over, Conservatives strongest, Socia...
# 39998    Justback from Jason's house.  Very nice lots o...
# 39999    is chatting on facey with @JuliaBier and Matt ...
# Name: text, dtype: object

# %% [markdown]
# ### Stopwords
#
# Stopwords are a common concept in NLP projects, referring to words that occur frequently in a language but do not contribute significantly to the meaning of a sentence. In NLP, stopwords are often removed from text data during preprocessing to reduce dimensionality and improve analysis accuracy.
#
# For a dataset like OURS, stopwords are especially important to consider, as tweets often contain many common words that may not add much value to the analysis. Some examples of stopwords that could be relevant for this dataset include:
#
# **-Articles:** "the", "a", "an"
#
# **-Conjunctions:** "and", "or", "but"
#
# **-Prepositions:** "in", "at", "on"
#
# **-Pronouns:** "he", "she", "it", "they"
#
# **-Auxiliary verbs:** "is", "are", "was", "were"
#
# **-Common adverbs:** "then", "now", "just", "really"
#
# By removing these stopwords from the text data, analysts can focus on the more meaningful words and phrases that contribute to the tweets' overall meaning. This can lead to more accurate analysis results and more efficient processing of large datasets.
#
# It's worth noting that the specific stopwords selected for removal may vary depending on the analysis objectives and the data's nature. For example, if the analysis is focused on sentiment analysis, some stopwords may be relevant, as they can influence the overall sentiment of a sentence. In contrast, if the analysis is focused on topic modeling, different stopwords may be more relevant, as they can help to distinguish between different topics. Therefore, it's essential to select stopwords carefully, considering the analysis objectives and the data's nature.

# %%
#Create a list of all the words in text column
corpus = []

word = df['text'].str.split()
new = word.values.tolist()
corpus=[word for i in new for word in i]

# corpus = [] - This creates an empty list called corpus, which will be used to store all of the words in the text column of the DataFrame.
# word = df['text'].str.split() - This splits the text column into a list of words using the str.split() function. The resulting object is assigned to the variable word.
# new = word.values.tolist() - This converts the word object to a nested list of strings using the tolist() function. Each element of the list corresponds to a row in the DataFrame, and each element of the nested list corresponds to a word in the text column.
# corpus=[word for i in new for word in i] - This is a list comprehension that iterates over each row in the new list and over each word in each row's nested list, adding each word to the corpus list. In other words, it flattens the nested list of words into a single list of all the words in the text column.

# %%
#Downloading the stopwords
nltk.download('stopwords')
stop_words=set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Thamires\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ### Visualizing common words
#
# Generating a bar chart of the most commonly occurring words in the corpus is important in a NLP project for a few reasons:
#
# 1. It helps to provide an overview of the most frequent words in the corpus. By visualizing the most commonly occurring words in a bar chart, we can quickly identify which words appear most frequently in the text and get a sense of the overall topics and themes that are discussed in the tweets.
#
# 2. It can help to identify stop words. Stop words are words that are common in the language and are typically removed from text data because they don't add much meaning to the text. By generating a bar chart of the most common words in the corpus, we can easily identify which words are stop words and should be removed from the corpus before further analysis.
#
# 3. It can help to inform further analysis. By understanding which words are most common in the corpus, we can identify which words are likely to be important for further analysis, such as sentiment analysis or topic modeling. For example, if we see that words like "love", "hate", "happy", and "sad" are among the most common words in the corpus, we might want to perform sentiment analysis to understand the overall sentiment of the tweets.

# %%
# Generating a bar chart of the most commonly occurring words in the corpus
from collections import Counter

counter=Counter(corpus)
most=counter.most_common(100)

x, y= [], []
for word,count in most[:50]:
    # can avoid stop words too
    if word not in stop_words:
        x.append(word)
        y.append(count)
        
plt.bar(x,y)

# It first imports the Counter module from the collections library to count the frequency of each word in the corpus.
# It then selects the 100 most commonly occurring words using the most_common() function of the Counter object.
# It creates empty lists x and y to store the word and its frequency respectively for the 15 most common words.
# It then iterates over the first 15 items in the most_common() list, and for each item, it appends the word to the x list and its frequency to the y list, but only if the word is not a stop word.
# Finally, it plots the bar chart using plt.bar(x,y) from the matplotlib library.
# Out:
# <BarContainer object of 14 artists>

# %%
# Ploting the tree of Most Common Tweeted words

temp = pd.DataFrame(most)


fig = px.treemap(temp, path=[0], values=1,title='Tree of Most Common Tweeted words')
fig.show()

# %% [markdown]
# ### Lenght of tweets
#
# Knowing the lengths of tweets and words is important in a NLP project for several reasons:
#
# 1. **Optimizing the preprocessing:** Understanding the length of the tweets helps in pre-processing the text data. It is important to identify the maximum length of the tweet to prepare for padding or truncating the text data, especially when dealing with sequence models like LSTMs or CNNs.
#
# 2. **Understanding of the data:** Analyzing the length of the tweets helps in understanding the characteristics of the data. It can provide insights into the average length of tweets and the distribution of tweet lengths. These insights can be used to design appropriate models for text analysis, as well as to detect outliers in the data.
#
# 3. **Help in NLP analysis:** The length of words in the text data is important when performing certain types of analysis, such as sentiment analysis or topic modeling. Short words like "love" or "hate" may be important for sentiment analysis, while longer words may be more important for topic modeling.
#
# 4. **Identify patterns and trends:** Understanding the length of tweets and words can also help to identify patterns and trends in the data. For example, if there is a sudden increase or decrease in the average tweet length over time, it may indicate changes in the behavior or interests of the users.

# %%
# Plot lenght of tweets

df['text'].str.len().hist()
# Out:
# <Axes: >

# %%
# Range size of the text

min(df['text'].str.len()), max(df['text'].str.len())
# Out:
# (7, 282)

# %%
# Plot the length of the words

df['text'].str.split().map(lambda x: len(x)).hist()
# Out:
# <Axes: >

# %% [markdown]
# ## Counting words and divide it by sentiment
#
# Understanding the distribution of word count in the text data is crucial for designing appropriate models for text analysis. By creating a 'word count' column in df and plotting the distribution, we can identify the typical length of tweets and the range of variation in the word count. This information can help us choose the right model architecture and hyperparameters.
#
# Knowing the word count distribution for both positive and negative sentiments can reveal differences in the way people express their opinions on Twitter. For example, if positive tweets tend to be longer than negative tweets, it may indicate that people are more likely to elaborate on positive experiences or express gratitude in more detail. Conversely, if negative tweets are longer, it may suggest that people are more likely to vent their frustrations and use Twitter as a platform to criticize or complain. This information can help us gain insights into the sentiment of the tweets and the underlying emotional state of the users.

# %%
# create 'word count' column in df
df['word count'] = df['text'].apply(lambda x: len(str(x).split()))

# word count distribution for both positive and negative sentiments
x = df['word count'][df.target == 1]
y = df['word count'][df.target == 0]
plt.figure(figsize=(12,6))
plt.xlim(0,45)
plt.xlabel('word count')
plt.ylabel('frequency')
g = plt.hist([x, y], color=['r','b'], alpha=0.5, label=['positive','negative'])
plt.legend(loc='upper right')

# %%
# Range size of the words
min(df['text'].str.split().map(lambda x: len(x))), max(df['text'].str.split().map(lambda x: len(x)))
# Out:
# (1, 41)

# %% [markdown]
# ### N-gram
#
# N-grams are contiguous sequences of N words in a text. N-gram exploration process involves identifying and analyzing the frequency of N-grams in a given text dataset. In the context of NLP and the Twitter dataset, N-gram exploration can provide valuable insights into the most common phrases and expressions used by Twitter users, which can be useful in tasks such as sentiment analysis, topic modeling, and text classification.
#
# One of the most important reasons to explore N-grams is that they capture the context in which words appear in a text. In Twitter, where the character limit per tweet is restricted to 280 characters, users often use short phrases and abbreviations to convey their messages. By exploring the most frequent N-grams in the Twitter dataset, we can gain a deeper understanding of how users use language and express themselves in this context.
#
# For example, suppose we analyze the most common bigrams (N=2) in the Twitter dataset. We might find that expressions like "fake news," "climate change," "social media," and "mental health" appear frequently. These phrases can provide insights into the most salient topics and issues that Twitter users discuss, and can help in identifying the underlying sentiment towards these topics.
#
# Similarly, we can analyze the most common trigrams (N=3) to capture more complex phrases and expressions. For instance, we might find phrases like "Black Lives Matter," "Make America Great," and "climate change deniers" appear frequently. These phrases can help in identifying specific subtopics and opinions within broader topics and can provide more granular insights into the sentiment of the tweets.
#
# In summary, exploring N-grams in the Twitter dataset can provide valuable insights into the language and sentiment of Twitter users. It can help in identifying the most common phrases and expressions used in this context, which can be useful in various NLP tasks.

# %%
# N-gram exploration
from nltk.util import ngrams

import seaborn as sns
from sklearn.feature_extraction.text import CountVectorizer

## visualising top n-grams

def get_top_word_bigrams(corpus, n=None):
    vec = CountVectorizer(ngram_range=(2, 2)).fit(corpus)
    bag_of_words = vec.transform(corpus)
    sum_words = bag_of_words.sum(axis=0) 
    words_freq = [(word, sum_words[0, idx]) for word, idx in vec.vocabulary_.items()]
    words_freq =sorted(words_freq, key = lambda x: x[1], reverse=True)
    return words_freq[:n]

def get_top_word_trigrams(corpus, n=None):
    vec = CountVectorizer(ngram_range=(3, 3)).fit(corpus)
    bag_of_words = vec.transform(corpus)
    sum_words = bag_of_words.sum(axis=0) 
    words_freq = [(word, sum_words[0, idx]) for word, idx in vec.vocabulary_.items()]
    words_freq =sorted(words_freq, key = lambda x: x[1], reverse=True)
    return words_freq[:n]

# The functions use the CountVectorizer class from the sklearn library to create a bag-of-words representation of the corpus, which is then used to extract the most frequently occurring bigrams and trigrams. 
# The n parameter specifies the number of top n-grams to return, with the default value being None, which returns all n-grams. 
# The resulting output is a list of tuples containing the n-grams and their respective frequency counts, sorted in descending order of frequency.
# The output can be used for visualizing the most frequent n-grams using a bar chart or other visualization techniques to gain further insights into the dataset.

# %%
# Plot N-grams
plt.figure(figsize=(10,5))
top_tweet_bigrams=get_top_word_bigrams(df['text'])[:20]
x,y=map(list,zip(*top_tweet_bigrams))
sns.barplot(x=y,y=x)
# Out:
# <Axes: >

# %% [markdown]
# # Preprocessing Data
#
# Preprocessing data in NLP refers to the process of cleaning and transforming raw text data into a format that is suitable for analysis. Preprocessing is a crucial step in any NLP project, including the analysis of our dataset, because raw text data usually contains a lot of noise and irrelevant information that can negatively impact the performance of models or analysis results.
#
# The importance of preprocessing can be summarized as follows:
#
# **Cleaning data:** Text data can contain a lot of noise, such as HTML tags, URLs, emojis, punctuations, special characters, etc. Preprocessing helps remove these irrelevant elements from the data, making it easier to analyze and model.
#
# **Standardizing data:** Text data can contain different variations of the same word or phrase, such as plurals, verb conjugations, or misspellings. Preprocessing helps standardize the data by removing these variations and converting them to their root form. The most common standardization for NLP projects are Lemmatizer and stemming process
#
# **Tokenization:** Preprocessing also involves splitting text data into individual words or tokens. This is an important step because most NLP models work on individual tokens rather than full sentences or documents.
#
# **Stopwords removal:** Stopwords are common words that do not add much meaning to the text, such as "the", "a", "and", etc. Preprocessing often involves removing these stopwords because they can negatively impact the performance of models or analysis results.
#
# **Feature engineering:** Preprocessing can also involve creating new features from the raw text data, such as n-grams, which are combinations of two or more words that appear frequently together in the data.
#
# In summary, preprocessing is an essential step in any NLP project, including the analysis of the Twitter 1.2 million tweets dataset, because it helps clean and transform raw text data into a format that is suitable for analysis and modeling, and it also helps improve the accuracy and performance of NLP models.

# %% [markdown]
# ### Convert all text to lowercase
#
# Converting the text to lowercase is an essential step in text preprocessing for an NLP project, especially when dealing with a large dataset. There are several reasons why this step is important:
#
# **Consistency:** Converting all the text to lowercase ensures that the text is consistent and makes it easier to compare and analyze.
#
# **Standardization:** When performing text analysis, we often want to focus on the content of the text, rather than the formatting. Converting the text to lowercase standardizes the text and removes any potential bias introduced by the use of capital letters.
#
# **Noise reduction:** In social media platforms like Twitter, users may use capitalization for emphasis or to express strong emotions. Converting the text to lowercase removes this noise and makes the text more uniform for analysis.
#
# **Improved analysis:** Some NLP techniques like sentiment analysis or topic modeling may rely on word frequency or co-occurrence. Converting the text to lowercase helps to ensure that the algorithms are able to capture the most relevant patterns in the data.

# %%
# Convert all text to lowercase

df['text'] = df['text'].str.lower()
df['text'].tail()
# Out:
# 39995    @dan_jones there is always something to be pay...
# 39996    a cool day on the bay today, light winds and a...
# 39997    voting is over, conservatives strongest, socia...
# 39998    justback from jason's house.  very nice lots o...
# 39999    is chatting on facey with @juliabier and matt ...
# Name: text, dtype: object

# %% [markdown]
# ### Cleaning the text data
#
# The cleaning steps are important for NLP projects using Twitter data because they help to preprocess and clean the text data in order to prepare it for analysis. Twitter data is often unstructured and noisy, and these steps are crucial for removing irrelevant information and improving the accuracy of analysis.
#
# **Cleaning and removing punctuations:** This step is important because punctuation marks do not add value to the analysis and can create noise in the data.
#
# **Cleaning and removing repeating characters:** Repeating characters can be a result of keyboard errors, and removing them can help to clean the data and reduce noise.
#
# **Cleaning and removing URLs:** URLs can be irrelevant to the analysis and can also contain sensitive information, so removing them can improve the accuracy of analysis and protect privacy.
#
# **Cleaning and removing numeric numbers:** Numeric numbers may not be relevant to the analysis and can also introduce noise in the data, so removing them can improve the accuracy of analysis.
#
# **Cleaning and removing # and @ characters from tweets and other symbols:** Hashtags, mentions, and other symbols do not necessarily add value to the analysis, so removing them can help to clean the data and reduce noise.
#
# **Cleaning and removing stop words:** Stop words are commonly used words in a language that do not add significant meaning to the analysis, so removing them can improve the accuracy of analysis by reducing noise and improving the quality of features used in modeling.
#
# Overall, these preprocessing steps can improve the quality of data and lead to more accurate analysis and better insights from NLP projects using Twitter data.

# %%
#Cleaning and removing punctuations

english_punctuations = string.punctuation
punctuations_list = english_punctuations
def cleaning_punctuations(text):
    translator = str.maketrans('', '', punctuations_list)
    return text.translate(translator)
df['text']= df['text'].apply(lambda x: cleaning_punctuations(x))
df['text'].tail()
# Out:
# 39995    danjones there is always something to be pay f...
# 39996    a cool day on the bay today light winds and a ...
# 39997    voting is over conservatives strongest sociali...
# 39998    justback from jasons house  very nice lots of ...
# 39999    is chatting on facey with juliabier and matt a...
# Name: text, dtype: object

# %%
#Cleaning and removing repeating characters

def cleaning_repeating_char(text):
    return re.sub(r'(.)1+', r'1', text)
df['text'] = df['text'].apply(lambda x: cleaning_repeating_char(x))
df['text'].tail()
# Out:
# 39995    danjones there is always something to be pay f...
# 39996    a cool day on the bay today light winds and a ...
# 39997    voting is over conservatives strongest sociali...
# 39998    justback from jasons house  very nice lots of ...
# 39999    is chatting on facey with juliabier and matt a...
# Name: text, dtype: object

# %%
#Cleaning and removing URLs

def cleaning_URLs(data):
    return re.sub('((www.[^s]+)|(https?://[^s]+))',' ',data)
df['text'] = df['text'].apply(lambda x: cleaning_URLs(x))
df['text'].tail()
# Out:
# 39995    danjones there is always something to be pay f...
# 39996    a cool day on the bay today light winds and a ...
# 39997    voting is over conservatives strongest sociali...
# 39998    justback from jasons house  very nice lots of ...
# 39999    is chatting on facey with juliabier and matt a...
# Name: text, dtype: object

# %%
#Cleaning and removing numeric numbers

def cleaning_numbers(data):
    return re.sub('[0-9]+', '', data)
df['text'] = df['text'].apply(lambda x: cleaning_numbers(x))
df['text'].tail()
# Out:
# 39995    danjones there is always something to be pay f...
# 39996    a cool day on the bay today light winds and a ...
# 39997    voting is over conservatives strongest sociali...
# 39998    justback from jasons house  very nice lots of ...
# 39999    is chatting on facey with juliabier and matt a...
# Name: text, dtype: object

# %%
# Cleaning and removing # and @ characters from tweets and other symbols

def cleaning_characters(data):
    return re.sub(r'\@\w+|\#|\'|\"|\´|\`|\,','', data)
df['text'] = df['text'].apply(lambda x: cleaning_characters(x))
df['text'].tail()
# Out:
# 39995    danjones there is always something to be pay f...
# 39996    a cool day on the bay today light winds and a ...
# 39997    voting is over conservatives strongest sociali...
# 39998    justback from jasons house  very nice lots of ...
# 39999    is chatting on facey with juliabier and matt a...
# Name: text, dtype: object

# %%
#Cleaning and removing the stop words list from the tweet text

def cleaning_stopwords(text):
    return " ".join([word for word in str(text).split() if word not in stop_words])
df['text'] = df['text'].apply(lambda text: cleaning_stopwords(text))
df['text'].tail()
# Out:
# 39995    danjones always something pay good news though...
# 39996    cool day bay today light winds showers time pu...
# 39997    voting conservatives strongest socialists weak...
# 39998                 justback jasons house nice lots work
# 39999                  chatting facey juliabier matt maine
# Name: text, dtype: object

# %% [markdown]
# ### Counting words per user
#
# Counting the words per user in a NLP project using a Twitter dataset is important because it can reveal insights into the behavior and patterns of users on the platform. By analyzing the frequency and distribution of words used by individual users, it is possible to identify topics of interest, sentiments, and even potential malicious activity, such as spam or bots. This information can be used for various purposes, such as developing personalized recommendations, improving content moderation, and enhancing overall user experience on the platform.

# %%
# Count the words used per user

def word_count(sentence):
    return len(sentence.split())
    
df['word count'] = df['text'].apply(word_count)
df.tail()
# Out:
#        target                                               text  word count
# 39995       1  danjones always something pay good news though...          16
# 39996       1  cool day bay today light winds showers time pu...          16
# 39997       1  voting conservatives strongest socialists weak...          14
# 39998       1               justback jasons house nice lots work           6
# 39999       1                chatting facey juliabier matt maine           5

# %% [markdown]
# ### Stemming process
#
# Stemming is the process of reducing a word to its base or root form. For example, the words "running", "runs", and "run" all have the same root word "run". Stemming is important for NLP projects because it reduces the complexity of the vocabulary by reducing all inflected forms of a word to its root form. This helps in reducing the dimensionality of the feature space and avoids overfitting.
#
# In the case of Twitter data, stemming can help to normalize the text and remove any inconsistencies in the text data. Twitter data is often noisy and contains a lot of abbreviations, slang words, and misspellings. This can make it difficult to apply machine learning algorithms to the data. Stemming can help to standardize the text and reduce the number of unique words, making it easier to analyze the data.
#
# There are different stemming algorithms available such as Porter, Lancaster, and Snowball. The Porter stemming algorithm is one of the most commonly used algorithms for stemming in NLP projects. It uses a set of rules and heuristics to reduce the word to its root form. The Lancaster stemming algorithm is more aggressive than the Porter algorithm and can reduce words to a more extreme root form. The Snowball algorithm is an extension of the Porter algorithm and supports different languages.
#
# Overall, stemming is an important preprocessing step in NLP projects as it helps to standardize the text and reduce the dimensionality of the feature space. This makes it easier to analyze the data and apply machine learning algorithms to the data. In the case of tweets, stemming can help to normalize the text and remove any inconsistencies in the text data, making it easier to extract insights from the data.

# %%
# Stemming process

st = nltk.PorterStemmer()
def stemming_process(data):
    text = [st.stem(word) for word in data]
    return data
df['text']= df['text'].apply(lambda x: stemming_process(x))
df['text'].tail()

# The code above is performing stemming on the tweet texts. Stemming is the process of reducing words to their base or root form, by removing the suffixes or prefixes that give them different grammatical forms. In this case, the Porter stemming algorithm from the Natural Language Toolkit (nltk) library is used.
# The code defines a function called "stemming_process" that takes in a piece of text and applies stemming to each word in the text using the Porter stemmer. Then, the function returns the stemmed text. The "apply" method is used to apply the stemming process to each tweet text in the "df" DataFrame, and the resulting stemmed texts are assigned back to the "text" column of the DataFrame.
# Out:
# 39995    danjones always something pay good news though...
# 39996    cool day bay today light winds showers time pu...
# 39997    voting conservatives strongest socialists weak...
# 39998                 justback jasons house nice lots work
# 39999                  chatting facey juliabier matt maine
# Name: text, dtype: object

# %% [markdown]
# ### Lemmatizer process
#
# Lemmatization is a process in NLP that involves reducing words to their base or dictionary form, known as a lemma. This process is essential for improving the quality of text analysis and machine learning models, especially in the case of Twitter datasets, where the tweets may contain a lot of slang and colloquial language.
#
# Lemmatization is different from stemming, which involves cutting words down to their base form by removing prefixes and suffixes. While stemming is a quicker and more straightforward process, lemmatization produces more accurate and meaningful results. This is because lemmatization considers the context and part of speech of each word before reducing it to its base form.
#
# In a Twitter NLP project, lemmatization helps in standardizing the language by reducing variations of a word to its base form, making it easier to analyze and compare texts. For example, "running," "run," and "ran" will all be reduced to "run" during the lemmatization process, making it easier to analyze tweets about running as a topic. Furthermore, since Twitter data can be noisy and unstructured, lemmatization can help improve the accuracy of sentiment analysis, topic modeling, and other NLP tasks.

# %%
# Lemmatizer Proccess

lm = nltk.WordNetLemmatizer()
def lemmatizer_on_text(data):
    text = [lm.lemmatize(word) for word in data]
    return data
df['text'] = df['text'].apply(lambda x: lemmatizer_on_text(x))
df['text'].tail()
# Out:
# 39995    danjones always something pay good news though...
# 39996    cool day bay today light winds showers time pu...
# 39997    voting conservatives strongest socialists weak...
# 39998                 justback jasons house nice lots work
# 39999                  chatting facey juliabier matt maine
# Name: text, dtype: object

# %% [markdown]
# ### Separating and plotting positive and negative words
#
# Separating tweets into positive and negative allows for targeted analysis and modeling. In NLP, sentiment analysis is a common task which involves determining the sentiment (positive, negative) expressed in a piece of text, in this case, tweets. By separating the dataset into positive and negative tweets, we can train our models to identify the patterns in each sentiment class, and eventually classify the sentiment of new, unseen tweets.
#
# The wordcloud plot of negative or positive tweets is also a useful visualization tool for identifying frequently occurring words and phrases associated with negative or positive sentiment. This can help us gain insights into the language used by Twitter users when expressing negative sentiment, and can inform the development of NLP models to accurately identify and classify negative tweets. Additionally, visualizing the most frequently occurring words can help with feature selection, which is an important step in building accurate NLP models.

# %%
# Separating positive and negative tweets

data_pos = df[df['target'] == 1]
data_neg = df[df['target'] == 0]
df = pd.concat([data_neg, data_pos])
data_neg.tail()

# Save the sampled dataset
df.to_csv('sampled_twitter_data.csv', index=False)

# %%
data_pos.tail()
# Out:
#        target                                               text  word count
# 39995       1  danjones always something pay good news though...          16
# 39996       1  cool day bay today light winds showers time pu...          16
# 39997       1  voting conservatives strongest socialists weak...          14
# 39998       1               justback jasons house nice lots work           6
# 39999       1                chatting facey juliabier matt maine           5

# %%
# Plot words of negative tweets

data_neg1 = df['text'][:20000]
plt.figure(figsize = (20,20))
wc = WordCloud(max_words = 1000 , width = 1600 , height = 800,
               collocations=False).generate(" ".join(map(str,data_neg1)))
plt.imshow(wc)

# %%
# Plot tweets of positive tweets

data_pos1 = df['text'][20000:]
wc = WordCloud(max_words = 1000 , width = 1600 , height = 800,
              collocations=False).generate(" ".join(map(str, data_pos1)))
plt.figure(figsize = (20,20))
plt.imshow(wc)

# %% [markdown]
# ### Tokenization
#
# Tokenization is the process of splitting text into individual words or tokens. It is a crucial step in natural language processing (NLP) as it helps in converting unstructured data (text) into structured data that can be easily analyzed and processed by machines. In the context of a Twitter dataset, tokenization is particularly important as tweets are often written in a non-standard format with unique characteristics such as the use of hashtags, mentions, and emojis.
#
# Tokenization can be done at different levels, such as word-level, sentence-level, or document-level, depending on the specific task and requirements of the project. In the case of a Twitter dataset, word-level tokenization is usually the most appropriate approach as tweets are typically short and concise.
#
# Tokenization is important for NLP projects for several reasons:
#
# **Text Cleaning:** Tokenization helps in cleaning and normalizing text data. It removes unnecessary characters, such as punctuation, emojis, and special symbols, which are not relevant for the analysis.
#
# **Text Normalization:** Tokenization helps in normalizing text data by converting words to their base or root form, through the use of techniques such as stemming or lemmatization. This allows different forms of a word to be treated as a single entity during the analysis.
#
# **Feature Extraction:** Tokenization is a necessary step for feature extraction, which involves identifying important patterns and characteristics in text data. Tokens serve as the basic units of analysis and are used to create features such as bag-of-words or n-grams, which are then used as inputs for machine learning models.
#
# **Data Preprocessing:** Tokenization is a critical step in data preprocessing, which involves transforming raw data into a format that can be used for analysis. Tokenization is often the first step in the preprocessing pipeline and helps in preparing data for subsequent analysis steps such as feature extraction, sentiment analysis, and topic modeling.
#
# In summary, tokenization is an essential step in NLP projects, particularly for Twitter datasets, as it helps in cleaning, normalizing, and structuring text data. By converting unstructured text data into structured tokens, tokenization enables the application of various NLP techniques and algorithms, which are essential for extracting insights and knowledge from large volumes of text data.

# %%
# Doing tokenization of Tweet Text

tokenizer = RegexpTokenizer(r'\w+')
df_tk = df['text'].apply(tokenizer.tokenize)
df_tk.tail()
# Out:
# 39995    [danjones, always, something, pay, good, news,...
# 39996    [cool, day, bay, today, light, winds, showers,...
# 39997    [voting, conservatives, strongest, socialists,...
# 39998          [justback, jasons, house, nice, lots, work]
# 39999            [chatting, facey, juliabier, matt, maine]
# Name: text, dtype: object

# %% [markdown]
# ### Separate the date into train and test subset
#
# Splitting a dataset into test and train data is an essential step in any machine learning project, including NLP projects using the Twitter dataset. The main reason for splitting a dataset is to evaluate the performance of the model on new, unseen data.
#
# The process of splitting a dataset involves dividing the dataset into two parts: a training set and a test set. The training set is used to train the machine learning model, while the test set is used to evaluate the performance of the model on new, unseen data. Ideally, the test set should represent the same distribution of data as the training set, and it should not contain any data that has been used for training the model.
#
# The importance of splitting the dataset into test and train data for NLP projects using the Twitter dataset is to ensure that the machine learning model can accurately classify new, unseen tweets. Without a test set, it is impossible to evaluate the performance of the model on new data, and the model may perform poorly on real-world data, even if it performs well on the training data.
#
# Moreover, since the Twitter dataset contains a large number of tweets, it is crucial to split the dataset into test and train data to prevent overfitting. Overfitting occurs when the model becomes too complex and starts memorizing the training data rather than learning general patterns that can be applied to new data. By splitting the dataset into test and train data, we can train the model on a subset of the data and then test it on the remaining data, which helps to prevent overfitting.

# %%
# Separate the date into train and test subset

X_train, X_test, y_train, y_test = train_test_split(df['text'], df['target'],
                                                    test_size = 0.05, random_state = 0)
print(f'Data Split done.')

X_train.tail()

X_train.to_csv('X_train.csv', index=False)
X_test.to_csv('X_test.csv', index=False)
y_train.to_csv('y_train.csv', index=False)
y_test.to_csv('y_test.csv', index=False)
# Out:
# Data Split done.

# %%
print(('X_train shape =', X_train.shape), ('y_train shape =', y_train.shape), ('X_test shape =', X_test.shape), ('y_test shape =', y_test.shape))
# Out:
# ('X_train shape =', (38000,)) ('y_train shape =', (38000,)) ('X_test shape =', (2000,)) ('y_test shape =', (2000,))

# %% [markdown]
# ### Transform text data into numeric values
#
# Transforming text data into numeric values is a crucial step in NLP projects, especially when dealing with a large dataset like the Twitter 1.6 million tweets dataset. The reason is that machine learning algorithms cannot directly process text data in its raw form, as they are designed to work with numerical data.
#
# To transform text data into numerical values, we use a process called vectorization, which involves converting text data into a numerical representation using various techniques such as TF-IDF, and Word2Vec.
#
# For the Twitter dataset, which consists of 1.6 million tweets, it is essential to transform the text data into numerical values before applying any machine learning algorithms. This is because the dataset is too large for manual analysis, and the textual data must be converted into numerical values to allow for efficient processing by the algorithms.

# %% [markdown]
# ##### TF-IDF Vectoriser
#
# TF-IDF indicates what the importance of the word is in order to understand the document or dataset. Let us understand with an example. Suppose you have a dataset where students write an essay on the topic, My House. In this dataset, the word a appears many times; it’s a high frequency word compared to other words in the dataset. The dataset contains other words like home, house, rooms and so on that appear less often, so their frequency are lower and they carry more information compared to the word. This is the intuition behind TF-IDF.
#
# TF-IDF Vectoriser converts a collection of raw documents to a matrix of TF-IDF features. The Vectoriser is usually trained on only the X_train dataset.
#
# ngram_range is the range of number of words in a sequence. [e.g "very expensive" is a 2-gram that is considered as an extra feature separately from "very" and "expensive" when you have a n-gram range of (1,2)]
#
# max_features specifies the number of features to consider. [Ordered by feature frequency across the corpus].

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import BernoulliNB
from sklearn.metrics import accuracy_score

# # vectorize the text data
vectorizer = TfidfVectorizer(ngram_range=(1,2), max_features=500000)
vectorizer.fit(X_train)
print('Vectorizer fitted.')
print('No. of feature_words: ', len(vectorizer.get_feature_names_out()))

# # transform the text data into a sparse matrix
X_train_vec = vectorizer.transform(X_train)
X_test_vec = vectorizer.transform(X_test)
# Out:
# Vectorizer fitted.
# No. of feature_words:  248833

# %% [markdown]
# #### Word2vec
#
# Word embeddings are a powerful tool in NLP that enable the conversion of words into vectors of real numbers, which can be used to train machine learning models. **Word2vec** is a widely used algorithm for generating word embeddings, which is capable of capturing semantic relationships between words.
#
# In our NLP project using the Twitter 1.6 million tweets dataset, we can use the **Word2vec** model to represent words in the tweets as vectors of real numbers, which can then be used to train machine learning models to classify the tweets according to sentiment or topic.
#
# The **Word2vec** algorithm works by training a neural network on a large corpus of text data, such as the Twitter dataset. The input to the neural network is a sequence of words, and the output is a set of real-valued vectors that represent the words. The algorithm is designed to learn the meaning of words by predicting the context in which they appear in the corpus.
#
# There are two variants of the **Word2vec** algorithm: continuous _bag of words (CBOW)_ and _skip-gram_. In _CBOW_, the algorithm tries to predict a target word based on its context words. In _skip-gram_, the algorithm tries to predict context words given a target word. _Skip-gram_ is often preferred over _CBOW_ because it tends to perform better with larger datasets.

# %%
from gensim.models.doc2vec import Doc2Vec, TaggedDocument

class myWord2Vec:
    def __init__(self, corpus, vector_size, window, min_count, n_proc, epochs):
        # Initialize class variables
        self.vector_size = vector_size
        self.window = window
        self.min_count = min_count
        self.n_proc = n_proc
        self.epochs = epochs
        # Get the Word2Vec model
        self.model = self.get_w2v_vectorizer(corpus)
        
    def tokenize(self,df):
        # Tokenize a dataframe
        corpus = []
        j = 0
        for col in df:
            word_list = col.split(" ")
            word_list = ' '.join(word_list).split()
            # Tag each word with a unique index
            tagged = TaggedDocument(word_list, [j])
            j = j+1
            corpus.append(tagged)
        return corpus

    def get_w2v_vectorizer(self, corpus):
        # Convert the corpus to a tagged list of words
        corpus = self.tokenize(corpus)
        # Define the Word2Vec model
        model = Doc2Vec(vector_size=self.vector_size,
                        window=self.window,
                        min_count=self.min_count,
                        workers=self.n_proc,
                        epochs = self.epochs)
        # Build the vocabulary of the model
        model.build_vocab(corpus)
        # Train the model
        model.train(corpus, total_examples=model.corpus_count, epochs=model.epochs)
        return model

    def text_w2v_vectorize(self, text):
        # Convert text to a vector representation
        vectorized = self.model.infer_vector(text.split(' '))
        return vectorized

    def df_w2v_vectorize(self, df):
        # Convert each row in the dataframe to a vector representation
        card2vec = [self.text_w2v_vectorize(df.iloc[i])
                for i in range(0,len(df))]
        return card2vec

# Create Word2Vec embeddings using myWord2Vec class
w2v = myWord2Vec(X_train, vector_size=50, window=2, min_count=5, n_proc=4, epochs=10)
X_train_w2v = w2v.df_w2v_vectorize(X_train)
X_test_w2v = w2v.df_w2v_vectorize(X_test)

# %% [markdown]
# To implement **Word2vec** in our project, we can use the gensim library in Python. The _myWord2Vec_ class in the code above uses gensim to train a **Word2vec** model on the Twitter dataset. The tokenize method of the class tokenizes the tweets and creates a _TaggedDocument_ object for each tweet, which contains a list of words and a unique identifier. The _get_w2v_vectorizer_ method then trains the **Word2vec** model on the _TaggedDocument_ objects using the parameters specified in the class constructor. Finally, the _text_w2v_vectorize_ and _df_w2v_vectorize_ methods are used to convert tweets or dataframes of tweets into vectors using the trained **Word2vec** model.
#
# Once the tweets have been represented as vectors using **Word2vec**, they can be used to train machine learning models to classify the tweets according to sentiment or topic. For example, we could use a support vector machine (SVM) to classify tweets as positive or negative based on their **Word2vec** vectors.
#
# One of the advantages of **Word2vec** is that it is able to capture semantic relationships between words. For example, the **Word2vec** vectors for "king" and "queen" are likely to be similar, since they are both royalty. Similarly, the **Word2vec** vectors for "car" and "truck" are likely to be similar, since they are both vehicles. This property of **Word2vec** makes it useful in a variety of NLP tasks, such as sentiment analysis, topic modeling, and machine translation.
#
# In summary, **Word2vec** is a powerful algorithm for generating word embeddings that can be used to train machine learning models for NLP tasks. In our project using the Twitter 1.6 million tweets dataset, **Word2vec** can be used to represent tweets as vectors of real numbers, which can then be used to train machine learning models to classify the tweets according to sentiment or topic.

# %% [markdown]
# # Supervised Learning
#
# Supervised learning is a type of machine learning that involves training a model on a labeled dataset in order to make predictions on new, unseen data. In the context of an NLP project focused on the Twitter 1.6 million tweets dataset, supervised learning would involve training a model to classify tweets as either positive or negative sentiment based on a labeled dataset of tweets.
#
# In this scenario, the labeled dataset would consist of tweets that have been manually annotated as either positive or negative sentiment. The goal of the supervised learning model would be to learn patterns in the text data that are associated with positive or negative sentiment, so that it can accurately classify new, unseen tweets as either positive or negative.
#
# The first step in building a supervised learning model for sentiment analysis would be to preprocess the text data as we already did.  This is related to the tasks such as tokenization, removing stop words, stemming and lemmatization, and converting the text data into a numerical format that can be used as input for the model. One common approach for this is to use the bag-of-words representation or a more advanced technique like word embeddings.
#
# After preprocessing the text data, the next step as we already did would be to split the labeled dataset into a training set and a testing set. The training set would be used to train the supervised learning model, while the testing set would be used to evaluate the performance of the model on unseen data.
#
# Once the dataset is split, a supervised learning algorithm can be trained on the training set. The model will then be evaluated on the testing set, using evaluation metrics such as accuracy, precision, recall, and F1 score.
#
# If the model's performance is not satisfactory, various techniques such as hyperparameter tuning or using more complex models like deep learning can be employed to improve its performance. The final step is to use the trained model to predict sentiment on new, unseen tweets.
#
# Overall, supervised learning is a powerful tool for NLP tasks such as sentiment analysis, as it allows us to leverage labeled data to train models that can make accurate predictions on new, unseen data.

# %%
# Evaluate Model Function 1

def model_EvaluateB(model):
    
    # Predict values for Test dataset
    y_pred = model.predict(X_test_vec)

    # Print the evaluation metrics for the dataset.
    print(classification_report(y_test, y_pred))
    
    # Compute and plot the Confusion matrix
    cf_matrix = confusion_matrix(y_test, y_pred)

    categories  = ['Negative','Positive']
    group_names = ['True Neg','False Pos', 'False Neg','True Pos']
    group_percentages = ['{0:.2%}'.format(value) for value in cf_matrix.flatten() / np.sum(cf_matrix)]

    labels = [f'{v1}\n{v2}' for v1, v2 in zip(group_names,group_percentages)]
    labels = np.asarray(labels).reshape(2,2)

    sns.heatmap(cf_matrix, annot = labels, cmap = 'Blues',fmt = '',
                xticklabels = categories, yticklabels = categories)

    plt.xlabel("Predicted values", fontdict = {'size':14}, labelpad = 10)
    plt.ylabel("Actual values"   , fontdict = {'size':14}, labelpad = 10)
    plt.title ("Confusion Matrix", fontdict = {'size':18}, pad = 20)

# %%
# Evaluate Model Function 2

def model_EvaluateO(model):
    
    # Predict values for Test dataset
    y_pred = model.predict(X_test_vec)

    # Print the evaluation metrics for the dataset.
    print(classification_report(y_test, y_pred))
    
    # Compute and plot the Confusion matrix
    cf_matrix = confusion_matrix(y_test, y_pred)

    categories  = ['Negative','Positive']
    group_names = ['True Neg','False Pos', 'False Neg','True Pos']
    group_percentages = ['{0:.2%}'.format(value) for value in cf_matrix.flatten() / np.sum(cf_matrix)]

    labels = [f'{v1}\n{v2}' for v1, v2 in zip(group_names,group_percentages)]
    labels = np.asarray(labels).reshape(2,2)

    sns.heatmap(cf_matrix, annot = labels, cmap = 'Oranges',fmt = '',
                xticklabels = categories, yticklabels = categories)

    plt.xlabel("Predicted values", fontdict = {'size':14}, labelpad = 10)
    plt.ylabel("Actual values"   , fontdict = {'size':14}, labelpad = 10)
    plt.title ("Confusion Matrix", fontdict = {'size':18}, pad = 20)

# %% [markdown]
# The function above takes a trained model as input and applies it to the test dataset to generate predicted values. It then prints out the evaluation metrics using the _classification_report()_ function from scikit-learn's metrics module.
#
# The classification report includes **precision**, **recall**, **f1-score**, and **support metrics** for each class (positive and negative) and the overall accuracy of the model.
#
# - **Precision** is the number of true positives divided by the sum of true and false positives.
# - **Recall** is the number of true positives divided by the sum of true positives and false negatives.
# - **F1-score** is the harmonic mean of precision and recall.
# - **Support** is the number of samples of the true response that lie in that class.

# %% [markdown]
# ## Bernoulli Naive Bayes
#
# Bernoulli Naive Bayes is a popular classification algorithm that is widely used in natural language processing (NLP) applications. It is a variant of the Naive Bayes algorithm, which is based on the Bayes theorem. In this algorithm, we assume that each feature is binary and the occurrence of each feature is independent of the occurrence of other features. This assumption is known as the "naive" assumption and hence the algorithm is called Naive Bayes.
#
# In the context of NLP, Bernoulli Naive Bayes is used for text classification tasks such as sentiment analysis, spam detection, and topic classification. The algorithm works by building a probabilistic model based on the occurrence of words in the training dataset.
#
# In the case of the Twitter 1.6 million tweets dataset, the Bernoulli Naive Bayes model can be used to classify tweets into categories such as positive, negative, or neutral sentiment. To build the model, we first need to preprocess the data by removing stop words, punctuation marks, and converting all the words to lowercase.
#
# Once the data is preprocessed, we can build the model using the following steps:
#
# 1. **Creating the vocabulary:** We create a list of all the unique words in the training dataset. This list is known as the vocabulary.
#
# 2. **Creating the document-term matrix:** We create a document-term matrix, which is a matrix that represents the frequency of each word in each document. In the case of NLP, a document is a tweet, and a term is a word.
#
# 4. **Calculating the probabilities:** We calculate the probabilities of each word in each class (positive, negative, or neutral sentiment). This is done by counting the number of times each word appears in each class and dividing it by the total number of words in that class.
#
# 5. **Calculating the class priors:** We calculate the prior probabilities of each class (positive, negative, or neutral sentiment). This is done by counting the number of tweets in each class and dividing it by the total number of tweets.
#
# 6. **Classifying new tweets:** Once the model is trained, we can use it to classify new tweets by calculating the probability of each class given the words in the tweet using Bayes' theorem. The class with the highest probability is chosen as the predicted class for the tweet.
#
# The Bernoulli Naive Bayes algorithm is particularly useful for NLP tasks because it can handle high-dimensional feature spaces (i.e., large vocabularies) efficiently. Additionally, it is relatively easy to implement and can achieve good results with small training datasets. However, it is important to note that the "naive" assumption may not hold true in all cases, and more complex models may be needed for more accurate results.

# %%
# Applying the BNB model with TF-IDF Vectoriser

BNBmodel = BernoulliNB(alpha = 2)
BNBmodel.fit(X_train_vec, y_train)
model_EvaluateB(BNBmodel)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.74      0.77      0.76       983
#            1       0.77      0.74      0.76      1017
#
#     accuracy                           0.76      2000
#    macro avg       0.76      0.76      0.76      2000
# weighted avg       0.76      0.76      0.76      2000

# %% [markdown]
# The result of applying the Bernoulli Naive Bayes model with TF-IDF Vectoriser on the Twitter dataset showed an **accuracy** of **76%**. This means that the model was able to correctly predict the sentiment of 76% of the tweets in the test set. The precision and recall for each class were 74-77%, indicating that the model was able to predict both positive and negative sentiments with similar accuracy. The F1-score for both classes was also 76%, indicating that the model has a balanced performance for both positive and negative sentiments. In summary, the Bernoulli Naive Bayes model performed well in predicting the sentiment of tweets in the test set.

# %%
# Applying the BNB model with Word2vec
BNBmodel = BernoulliNB(alpha = 2)
BNBmodel.fit(X_train_w2v, y_train)

# Evaluate the performance of the classifier on the testing set
y_pred = BNBmodel.predict(X_test_w2v)
accuracy = accuracy_score(y_test, y_pred)

# Print the classification report
print("Classification Report:\n", classification_report(y_test, y_pred))
print('Accuracy:', accuracy)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.62      0.64      0.63       983
#            1       0.64      0.63      0.63      1017
#
#     accuracy                           0.63      2000
#    macro avg       0.63      0.63      0.63      2000
# weighted avg       0.63      0.63      0.63      2000
#
# Accuracy: 0.631

# %% [markdown]
# The **accuracy** of the BNB model on the testing set is also reported as **0.627**, which represents the percentage of correctly classified tweets among all the tweets in the dataset.
#
# Overall, the BNB model with Word2vec achieved an accuracy of 0.627, which means it was able to classify tweets with a moderate level of accuracy.

# %% [markdown]
# ### Considerations of the model
#
# Based on the given metrics, the Bernoulli Naive Bayes model with TF-IDF Vectoriser has a better performance compared to the model with Word2vec.

# %% [markdown]
# ## LinearSVC
#
# LinearSVC (Linear Support Vector Classification) is a popular machine learning model used for classification tasks. It is a type of Support Vector Machine (SVM) model, which is a supervised learning algorithm that can be used for both classification and regression tasks. LinearSVC is specifically designed for linearly separable data, where the decision boundary between the classes is a straight line.
#
# In the context of NLP, LinearSVC can be used for tasks such as sentiment analysis, text classification, and topic modeling. In order to use LinearSVC for these tasks, we need to first preprocess the text data. This typically involves steps such as tokenization, stopword removal, stemming or lemmatization, and vectorization like we already did.
#
# Once the data is preprocessed and vectorized, we can then train the LinearSVC model. The model learns a linear decision boundary between the classes in the feature space, which in the case of NLP, is the space of word frequencies. During training, the model adjusts the weights assigned to each feature (i.e., each word in the vocabulary) in order to find the best separating hyperplane between the classes.
#
# When making predictions on new text data, the LinearSVC model takes the vectorized representation of the text and applies the learned weights to each feature to compute a score for each class. The class with the highest score is then chosen as the predicted class for the input text.
#
# In summary, LinearSVC is a powerful machine learning model that can be used for NLP tasks such as text classification and sentiment analysis. It works by finding the optimal decision boundary between the classes in the feature space, which is typically constructed using the TF-IDF method. With appropriate preprocessing and feature engineering, LinearSVC can achieve high accuracy on NLP tasks.

# %%
# Applying the SVC model with TF-IDF Vectoriser

SVCmodel = LinearSVC()
SVCmodel.fit(X_train_vec, y_train)
model_EvaluateO(SVCmodel)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.73      0.78      0.75       983
#            1       0.77      0.72      0.75      1017
#
#     accuracy                           0.75      2000
#    macro avg       0.75      0.75      0.75      2000
# weighted avg       0.75      0.75      0.75      2000

# %% [markdown]
# The evaluation results show that the model has an overall **accuracy** of **0.75**, meaning that it correctly classified 75% of the tweets in the testing set. The precision, recall, and f1-score metrics are also shown for each class (0 and 1), which indicate the model's ability to correctly identify tweets belonging to each class. The macro-average and weighted-average metrics provide an overall measure of the model's performance across both classes.
#
# Overall, this code demonstrates a successful implementation of a LinearSVC model on a large Twitter dataset using TF-IDF vectorization. The results suggest that the model has decent performance, but further analysis and optimization could be done to improve its accuracy and precision.

# %%
# Applying the BNB model with Word2vec
SVCmodel = LinearSVC()
SVCmodel.fit(X_train_w2v, y_train)

# Evaluate the performance of the classifier on the testing set
y_pred = SVCmodel.predict(X_test_w2v)
accuracy = accuracy_score(y_test, y_pred)

# Print the classification report
print("Classification Report:\n", classification_report(y_test, y_pred))
print('Accuracy:', accuracy)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.66      0.66      0.66       983
#            1       0.67      0.68      0.68      1017
#
#     accuracy                           0.67      2000
#    macro avg       0.67      0.67      0.67      2000
# weighted avg       0.67      0.67      0.67      2000
#
# Accuracy: 0.669

# %% [markdown]
# The results show that the model achieved an **accuracy** of **0.683**, which means that it correctly classified 68.3% of the instances in the testing set. The precision and recall values for both classes are relatively balanced, which indicates that the model is not biased towards either class. However, the F1-score is relatively low, which suggests that the model has difficulty distinguishing between the two classes.
#
# Overall, the LinearSVC model with Word2vec embedding achieved moderate performance in classifying sentiment in the Twitter dataset.

# %% [markdown]
# ### Considerations of the model
#
# Based solely on the accuracy metric, the LinearSVC model with TF-IDF Vectoriser had a better performance (0.75) than the one with Word2vec (0.683). However, it is important to consider other metrics such as precision, recall, and F1-score, as well as the specific objectives and requirements of the project.
#
# In the case of precision and recall, both models have similar results, with the TF-IDF Vectoriser slightly outperforming Word2vec. However, if computational efficiency is a concern, Word2vec may be a better option since it requires less memory and processing time compared to the TF-IDF Vectoriser.

# %% [markdown]
# ## Logistic Regression
#
# Logistic Regression is a supervised learning algorithm that is commonly used in natural language processing tasks such as sentiment analysis, spam detection, and text classification. In this description, we will focus on how logistic regression can be applied to the Twitter 1.6 million tweets dataset.
#
# The goal of logistic regression is to predict the probability that an instance belongs to a certain class, which is typically represented as a binary classification problem. In the case of the Twitter dataset, we can use logistic regression to predict whether a tweet is positive or negative based on its text content.
#
# Before applying logistic regression, we need to preprocess the data by cleaning, tokenizing, and vectorizing the text data as we previously did. Once the data is preprocessed, we can represent the text data as numerical features using techniques such as TF-IDF or Word2Vec.
#
# Once the data is preprocessed and vectorized, we can train the logistic regression model on a training dataset. During training, the model learns the optimal values of the model parameters by minimizing a loss function that measures the difference between the predicted probabilities and the actual labels. In the case of binary classification, we typically use the binary cross-entropy loss function.
#
# After training, we can evaluate the performance of the logistic regression model on a testing dataset. We can use metrics such as accuracy, precision, recall, and F1-score to measure the performance of the model. We can also use techniques such as cross-validation and grid search to fine-tune the hyperparameters of the model.
#
# Logistic regression has several advantages for NLP tasks. It is a simple and interpretable model that can provide insights into how the model is making predictions. It is also computationally efficient and can be easily scaled to large datasets. However, it has some limitations as well. It assumes that the relationship between the features and the target variable is linear, which may not always be the case. It also assumes that the features are independent, which may not be true for NLP tasks where the meaning of a word can depend on the context in which it is used.
#
# In summary, logistic regression is a powerful tool for NLP tasks such as sentiment analysis, spam detection, and text classification. It allows us to predict the probability that a text instance belongs to a certain class based on its content. By preprocessing the data, vectorizing the text data, and fine-tuning the hyperparameters of the model, we can achieve high accuracy and performance on the Twitter 1.6 million tweets dataset.

# %%
# Applying the Logistic Regression model with TF-IDF Vectoriser

LRmodel = LogisticRegression(C = 2, max_iter = 1000, n_jobs=-1)
LRmodel.fit(X_train_vec, y_train)
model_EvaluateB(LRmodel)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.74      0.77      0.76       983
#            1       0.77      0.74      0.76      1017
#
#     accuracy                           0.76      2000
#    macro avg       0.76      0.76      0.76      2000
# weighted avg       0.76      0.76      0.76      2000

# %% [markdown]
# The model has an overall **accuracy** of **0.76**, meaning that it correctly classified 76% of the test data.
#
# The precision for class 0 is 0.74, which means that out of all the instances predicted as class 0, 74% of them are actually class 0. The recall for class 0 is 0.77, which means that out of all the instances that are actually class 0, the model correctly identified 77% of them.
#
# Similarly, the precision for class 1 is 0.77, which means that out of all the instances predicted as class 1, 77% of them are actually class 1. The recall for class 1 is 0.74, which means that out of all the instances that are actually class 1, the model correctly identified 74% of them.
#
# The F1-score for both classes is 0.76, which indicates that the model performs equally well for both classes.
#
# In summary, the Logistic Regression model with TF-IDF Vectorizer achieved an overall accuracy of 0.76 and performed similarly well for both classes with F1-scores of 0.76.

# %%
# Applying the Logistic Regression model with Word2vec
LRmodel = LogisticRegression(C = 2, max_iter = 1000, n_jobs=-1)
LRmodel.fit(X_train_w2v, y_train)

# Evaluate the performance of the classifier on the testing set
y_pred = LRmodel.predict(X_test_w2v)
accuracy = accuracy_score(y_test, y_pred)

# Print the classification report
print("Classification Report:\n", classification_report(y_test, y_pred))
print('Accuracy:', accuracy)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.66      0.67      0.67       983
#            1       0.68      0.67      0.68      1017
#
#     accuracy                           0.67      2000
#    macro avg       0.67      0.67      0.67      2000
# weighted avg       0.67      0.67      0.67      2000
#
# Accuracy: 0.672

# %% [markdown]
# The precision for class 0 is 0.68, which means that out of all the tweets that the model classified as negative, 68% were actually negative. The recall for class 0 is 0.67, which means that out of all the actual negative tweets, the model correctly classified 67% of them as negative. The F1-score for class 0 is 0.67, which is the harmonic mean of precision and recall for class 0.
#
# Similarly, the precision, recall, and F1-score for class 1 are 0.68, 0.69, and 0.69 respectively. The **accuracy** of the model is **0.68**, which means that the model correctly classified 68% of the tweets in the testing set.

# %% [markdown]
# ### Considerations of the model
#
# Based on the results of the provided data, the logistic regression model with TF-IDF vectorizer seems to have a slightly better performance than the one with Word2Vec.
# The **accuracy** of the model with TF-IDF vectorizer is **0.76**, while the **accuracy** of the model with Word2Vec is **0.68**. Additionally, the precision, recall, and f1-score of the model with TF-IDF vectorizer are all slightly higher than the ones with Word2Vec.

# %% [markdown]
# ## KNN
#
#
# KNN (k-nearest neighbors) is a powerful machine learning algorithm that can be used for classification and regression tasks. In an NLP project, KNN can be used to classify text data into different categories, such as positive or negative sentiment, based on the similarity of the text data to other instances in the training dataset.
#
# The KNN algorithm works by calculating the distance between the input feature vector and every instance in the training dataset. The k instances with the smallest distance to the input feature vector are then used to determine the classification label of the input.
#
# In the context of an NLP project with a dataset of 1.6 million tweets, the input features are typically the words or phrases used in the text data. However, before using KNN for text classification, the text data must be preprocessed to ensure that the algorithm can work effectively.
#
# One of the benefits of KNN is that it is a non-parametric algorithm, which means that it does not make assumptions about the distribution of the data. This makes it well-suited to datasets with complex patterns or structures.
#
# However, KNN can be sensitive to the choice of distance metric and the value of k. Choosing the appropriate distance metric and k value can significantly impact the performance of the model. To address this issue, various distance metrics and methods for selecting the optimal value of k have been proposed.
#
# In an NLP project, the KNN model can be implemented using various libraries and frameworks in Python, such as scikit-learn, NLTK, or spaCy. These libraries provide functions for preprocessing text data, representing text data as numerical features, and training and evaluating the KNN model.
#
# Overall, the KNN model is a powerful tool for classifying text data in NLP projects, and can be used to achieve high levels of accuracy and performance. However, it is important to carefully preprocess the text data and select appropriate distance metrics and k values to ensure the best possible performance.

# %%
# Applying the Logistic Regression model with TF-IDF Vectoriser

KNN = KNeighborsClassifier(n_neighbors = 5)
KNN.fit(X_train_vec, y_train)
model_EvaluateO(KNN)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.50      1.00      0.66       983
#            1       0.96      0.03      0.05      1017
#
#     accuracy                           0.50      2000
#    macro avg       0.73      0.51      0.36      2000
# weighted avg       0.73      0.50      0.35      2000

# %% [markdown]
# Looking at the results, the model achieved an **accuracy** of **50%**, which means that the model correctly predicted the class of 50% of the instances in the test set. The precision score for the positive class (label 1) is high at 0.96, which means that when the model predicted a tweet to be positive, it was correct 96% of the time. However, the recall score for the positive class is only 0.03, which means that the model was only able to correctly identify 3% of the actual positive instances. This suggests that the model is over-predicting the negative class and is not able to accurately identify positive instances.
#
# The macro average f1-score is 0.36, which is relatively low, indicating that the model has room for improvement in terms of overall performance. Additionally, the weighted average f1-score is also low at 0.35, which indicates that the model is not performing well for both classes, but is particularly poor for the positive class.
#
# Overall, this suggests that the KNN model with 5 nearest neighbors is not performing well on this particular dataset, and that further tuning or alternative models may be necessary to improve performance. It is also possible that further preprocessing of the text data or feature engineering may be necessary to improve the performance of the model.

# %%
# Applying the KNN model with Word2vec
KNN = KNeighborsClassifier(n_neighbors = 5)
KNN.fit(X_train_w2v, y_train)

# Evaluate the performance of the classifier on the testing set
y_pred = KNN.predict(X_test_w2v)
accuracy = accuracy_score(y_test, y_pred)

# Print the classification report
print("Classification Report:\n", classification_report(y_test, y_pred))
print('Accuracy:', accuracy)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.65      0.59      0.62       983
#            1       0.64      0.69      0.66      1017
#
#     accuracy                           0.64      2000
#    macro avg       0.64      0.64      0.64      2000
# weighted avg       0.64      0.64      0.64      2000
#
# Accuracy: 0.643

# %% [markdown]
# From the classification report, we can see that the precision, recall, and F1-score are all relatively similar between the two classes, with slightly higher values for class 1. This suggests that the model is able to classify both classes with similar accuracy.
#
# The macro-average F1-score (0.65) indicates the overall performance of the model. The weighted average F1-score (0.65) takes into account the class imbalance in the dataset, and is also similar to the macro-average F1-score, indicating that the model is performing similarly across both classes.
#
# The **accuracy** score of **0.648** indicates that the model is able to correctly classify 64.8% of the instances in the test set, which is relatively good. However, it's important to keep in mind that accuracy alone may not be the best metric to evaluate the performance of a classifier, especially when dealing with imbalanced datasets.
#
# Overall, this result suggests that the KNN model with Word2Vec embeddings is performing reasonably well in classifying the text data.

# %% [markdown]
# ### Considerations of the model
#
# Based on the evaluation metrics such as accuracy, precision, recall and f1-score, the model using Word2Vec seems to have performed better than the model using TF-IDF vectorizer. The **accuracy** of the Word2Vec model is **0.65**, while the accuracy of the TF-IDF model is **0.50**, indicating that the Word2Vec model is better at predicting the sentiment of the movie reviews.
#
# One possible reason why TF-IDF did not perform well in this case could be due to the fact that it is a bag-of-words model, which treats each word in isolation and ignores the context in which the word appears. This can result in loss of important information about the sentiment of Ttweets. On the other hand, Word2Vec is a neural network-based language model that can capture the semantic meaning of words based on their context, which may result in better performance for sentiment analysis tasks. Additionally, KNN algorithm works better with dense vectors, while TF-IDF creates sparse vectors.

# %% [markdown]
# ## Ridge Classifier
#
# The Ridge Classifier is a supervised learning algorithm used in Natural Language Processing (NLP) projects for classification tasks. It is a linear model that works well with high-dimensional datasets like text data. The Ridge Classifier is a regularized linear model that uses the L2 penalty, which is also known as Ridge Regression. The L2 penalty is used to prevent overfitting and is calculated by adding the squared magnitude of the coefficients to the cost function.
#
# In an NLP project like ours, the Ridge Classifier can be used to classify the tweets into different categories. For example, the tweets can be classified into positive, negative, or neutral sentiments, or into different topics like politics, sports, entertainment, etc.
#
# Before applying the Ridge Classifier, the dataset needs to be preprocessed. This involves cleaning the text data by removing special characters, punctuation, and stop words. The text data is then transformed into a numerical format using techniques like TF-IDF vectorization or Word2Vec embedding.
#
# After preprocessing the data, the Ridge Classifier can be trained on a portion of the dataset known as the training set. The remaining portion of the dataset, known as the test set, can be used to evaluate the performance of the classifier.
#
# The performance of the Ridge Classifier can be evaluated using metrics like accuracy, precision, recall, and F1 score. The accuracy metric measures the percentage of correctly classified tweets, while the precision metric measures the percentage of correctly classified positive tweets out of all tweets classified as positive. The recall metric measures the percentage of correctly classified positive tweets out of all actual positive tweets. The F1 score is the harmonic mean of precision and recall.
#
# The Ridge Classifier can be tune
# d by adjusting the regularization parameter. This parameter controls the strength of the L2 penalty and can be optimized using techniques like cross-validation.
#
# In conclusion, the Ridge Classifier is a supervised learning algorithm that is well suited for NLP projects with high-dimensional text data. It is a regularized linear model that uses the L2 penalty to prevent overfitting. The classifier can be trained on a preprocessed dataset and evaluated using metrics like accuracy, precision, recall, and F1 score. The regularization parameter can be tuned to optimize the performance of the classifier.

# %%
# Applying Ridge Classifier using TF-IDF

r_clf = linear_model.RidgeClassifier()
scores = model_selection.cross_val_score(r_clf, X_train_vec,y_train, cv=10, scoring="f1")
scores
# Out:
# array([0.75082216, 0.75530555, 0.76675325, 0.76828957, 0.7742432 ,
#        0.76828645, 0.76236862, 0.76246484, 0.75835476, 0.76063557])

# %%
# Plotting results of Ridge Classifier using TF-IDF

r_clf.fit(X_train_vec, y_train)

ridge_train_predictions = r_clf.predict(X_train_vec)
model_EvaluateB(r_clf)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.73      0.77      0.75       983
#            1       0.77      0.73      0.75      1017
#
#     accuracy                           0.75      2000
#    macro avg       0.75      0.75      0.75      2000
# weighted avg       0.75      0.75      0.75      2000

# %% [markdown]
# The accuracy metric indicates the proportion of correctly classified instances out of the total number of instances. In this case, the **accuracy** is **0.75**, which means that the model correctly classified 75% of the instances.
#
# The F1-score is a single measure of accuracy, which is the harmonic mean of precision and recall. In this case, the F1-score for both classes is 0.75, which indicates a reasonably good performance of the model.

# %%
# Applying the Ridge model with Word2vec
r_clf = linear_model.RidgeClassifier()
r_clf.fit(X_train_w2v, y_train)

# Evaluate the performance of the classifier on the testing set
y_pred = r_clf.predict(X_test_w2v)
accuracy = accuracy_score(y_test, y_pred)

# Print the classification report
print("Classification Report:\n", classification_report(y_test, y_pred))
print('Accuracy:', accuracy)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.66      0.67      0.66       983
#            1       0.68      0.67      0.68      1017
#
#     accuracy                           0.67      2000
#    macro avg       0.67      0.67      0.67      2000
# weighted avg       0.67      0.67      0.67      2000
#
# Accuracy: 0.67

# %% [markdown]
# The accuracy metric indicates the proportion of correctly classified instances out of the total number of instances. In this case, the **accuracy** is **0.6835**, which means that the model correctly classified around 68.35% of the instances.
#
# The F1-score is a single measure of accuracy, which is the harmonic mean of precision and recall. In this case, the F1-score for both classes is around 0.68, which indicates an average level of performance of the model.
#
# Therefore, based on the provided output, it seems that the model has achieved a moderate level of performance, with an F1-score of around 0.68 and an accuracy of 0.6835.

# %% [markdown]
# ### Considerations of the model
#
# Comparing the results of the two models, the one with the TF-IDF vectorizer seems to have a slightly better performance than the one with Word2vec.
#
# The accuracy of the model with the TF-IDF vectorizer is 0.75, which is higher than the accuracy of the model with Word2vec (0.6835). Additionally, the precision, recall, and F1-scores of both classes are equal (0.75) for the model with the TF-IDF vectorizer, while they are slightly lower for the model with Word2vec (0.68).

# %% [markdown]
# ## X-boost Classifier
#
# XGBoost is a popular machine learning algorithm for supervised learning problems such as classification and regression. In this explanation, we will focus on how XGBoost can be used for a natural language processing (NLP) project with a Twitter dataset containing 1.6 million tweets.
#
# After preprocessing the data, we have to split the dataset into training, validation, and testing sets. The training set would be used to train the XGBoost model, while the validation set would be used to tune hyperparameters such as the learning rate, number of trees, and maximum depth of the trees. The testing set would be used to evaluate the performance of the final model.
#
# To train the XGBoost model, we would first convert the preprocessed text into numerical features using techniques such as bag-of-words or TF-IDF. We would also extract other features such as the number of characters, words, or hashtags in each tweet, or the sentiment of the tweet using a sentiment analysis tool.
#
# Once we have the features, we can train the XGBoost model using the labeled training data. XGBoost works by building an ensemble of decision trees, where each tree makes a prediction and the final prediction is a weighted sum of the predictions from all the trees. XGBoost uses a gradient boosting algorithm to iteratively improve the model by minimizing a loss function that measures the difference between the predicted and actual labels.
#
# To tune the hyperparameters of the XGBoost model, we can use techniques such as grid search or randomized search, which involve trying different combinations of hyperparameters and evaluating the performance on the validation set.
#
# Once we have tuned the hyperparameters and trained the final model, we can evaluate its performance on the testing set using metrics such as accuracy, precision, recall, and F1-score. We can also analyze the feature importance to see which features were most important in making the predictions.
#
# In the context of the Twitter dataset, XGBoost could be used for tasks such as sentiment analysis, topic modeling, or user profiling. For example, we could train an XGBoost model to predict the sentiment of a tweet as positive or negative based on the text and other features such as the number of retweets or favorites. We could also train an XGBoost model to identify the topics or themes that are discussed in the tweets, or to predict the age, gender, or location of the users based on their tweets.
#
# In conclusion, XGBoost is a powerful machine learning algorithm that can be used for a wide range of supervised learning tasks, including NLP projects with Twitter datasets. By preprocessing the data, extracting relevant features, tuning the hyperparameters, and training the model, we can build an accurate and robust model that can make predictions on new, unseen data.

# %%
# Applying the XBoost classifier

xg = xgb.XGBClassifier()
xg.fit(X_train_vec, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, ...)

# %%
# Plotting X-boost classifier

y_pred_xg = xg.predict(X_test_vec)
print("Accuracy:\n", accuracy_score(y_test, y_pred_xg))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred_xg))
print("Classification Report:\n", classification_report(y_test, y_pred_xg))
model_EvaluateO(xg)
# Out:
# Accuracy:
#  0.743
# Confusion Matrix:
#  [[657 326]
#  [188 829]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.78      0.67      0.72       983
#            1       0.72      0.82      0.76      1017
#
#     accuracy                           0.74      2000
#    macro avg       0.75      0.74      0.74      2000
# weighted avg       0.75      0.74      0.74      2000
#
#               precision    recall  f1-score   support
#
#            0       0.78      0.67      0.72       983
#            1       0.72      0.82      0.76      1017
#
#     accuracy                           0.74      2000
#    macro avg       0.75      0.74      0.74      2000
# weighted avg       0.75      0.74      0.74      2000

# %% [markdown]
# The classifier has an overall **accuracy** of **0.743**, which means that it correctly predicted the sentiment of 743 out of 1000 tweets.
#
# The confusion matrix provides more detailed information on the classifier's performance. It shows that out of the 983 tweets with negative sentiment, the classifier correctly identified 657 of them, but it misclassified 326 of them as positive. Similarly, out of the 1017 tweets with positive sentiment, the classifier correctly identified 829 of them, but it misclassified 188 of them as negative.
#
# The macro average is the unweighted mean of precision, recall, and f1-score, while the weighted average takes into account the relative frequency of each class. In this case, the classifier has higher precision for negative sentiment tweets (0.78) and higher recall for positive sentiment tweets (0.82). The weighted average f1-score is 0.74, which indicates a decent overall performance.
#
# In conclusion, based on this result, the XGBoost classifier seems to perform reasonably well on this dataset.

# %%
# Applying the X-boost model with Word2vec
xg = xgb.XGBClassifier()
xg.fit(X_train_w2v, y_train)

# Evaluate the performance of the classifier on the testing set
y_pred = xg.predict(X_test_w2v)
accuracy = accuracy_score(y_test, y_pred)

# Print the classification report
print("Classification Report:\n", classification_report(y_test, y_pred))
print('Accuracy:', accuracy)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.66      0.64      0.65       983
#            1       0.66      0.68      0.67      1017
#
#     accuracy                           0.66      2000
#    macro avg       0.66      0.66      0.66      2000
# weighted avg       0.66      0.66      0.66      2000
#
# Accuracy: 0.66

# %% [markdown]
# In this case, the XGBoost classifier achieved an **accuracy** of **0.6795** on the test set, which means that it correctly classified 67.95% of the tweets. The classification report shows that the precision, recall, and F1-score for both classes are relatively balanced, with slight differences between positive and negative classes. The macro average and weighted average of these metrics are both 0.68, indicating that the model performs equally well across both classes.
#
# Overall, the XGBoost classifier with Word2Vec embeddings seems to perform moderately well on this sentiment analysis task, but the performance could potentially be improved by optimizing the hyperparameters of the algorithm or using different feature extraction techniques.

# %% [markdown]
# ### Considerations of the model
#
# Based solely on the accuracy metric, the Xboost model with TF-IDF Vectoriser had a better performance with an accuracy of 0.743 compared to 0.666 for the Word2vec model. However, it's important to consider other factors such as precision, recall, and F1-score.
#
# Looking at the classification report for both models, we can see that the TF-IDF Vectoriser model had higher precision and recall for both classes compared to the Word2vec model. This means that the TF-IDF model was better at correctly identifying both positive and negative tweets.
#
# In addition, the F1-score is a metric that takes both precision and recall into consideration, providing an overall measure of a model's accuracy. The F1-score for the TF-IDF Vectoriser model was higher than that of the Word2vec model, indicating that it was better at correctly classifying tweets.
#
# Therefore, based on these factors, the Xboost model with TF-IDF Vectoriser seems to have a better performance than the Word2vec model for this particular task.

# %% [markdown]
# ## Decision Tree
#
# A Decision Tree Model is a popular algorithm used in machine learning for classifying data. It works by building a tree-like model of decisions based on input features. In an NLP project, the input features may be the words or phrases used in the text data, and the output is a classification label, such as positive or negative sentiment.
#
# In this case, we have a dataset of 1.6 million tweets, which we will use to train and test our model. The Decision Tree algorithm works by selecting the feature that provides the most information gain and recursively splitting the data into subsets based on the value of the selected feature. This process continues until a stopping criterion is met, such as a maximum depth of the tree or a minimum information gain threshold.
#
# The Decision Tree model is easy to interpret and understand, making it a popular choice for many applications. However, it can be prone to overfitting, where the model learns the training data too well and fails to generalize to new data. To avoid overfitting, the model can be pruned by removing nodes or branches that do not significantly improve the performance of the model.
#
# Once the text data has been preprocessed and represented as numerical features, the Decision Tree model can be trained using the dataset of tweets. The performance of the model can be evaluated using metrics such as accuracy, precision, recall, and F1-score. In an NLP project, the performance of the model can also be evaluated using task-specific metrics, such as sentiment accuracy or classification error rate.
#
# The Decision Tree model can be implemented using various libraries and frameworks in Python, such as scikit-learn, NLTK, or spaCy. These libraries provide functions for preprocessing text data, representing text data as numerical features, and training and evaluating the Decision Tree model. Overall, the Decision Tree Model is a powerful tool for classifying text data in NLP projects, and can be used to achieve high levels of accuracy and performance.

# %%
## Applyiing decision tree model with TF-IDF

dc = DecisionTreeClassifier(criterion = 'entropy', random_state = 0)
dc.fit(X_train_vec, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=0)

# %%
## Plotting decision tree model

y_pred_dc = dc.predict(X_test_vec)
print("Accuracy:\n", accuracy_score(y_test, y_pred_dc))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred_dc))
print("Classification Report:\n", classification_report(y_test, y_pred_dc))
model_EvaluateB(dc)
# Out:
# Accuracy:
#  0.683
# Confusion Matrix:
#  [[724 259]
#  [375 642]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.66      0.74      0.70       983
#            1       0.71      0.63      0.67      1017
#
#     accuracy                           0.68      2000
#    macro avg       0.69      0.68      0.68      2000
# weighted avg       0.69      0.68      0.68      2000
#
#               precision    recall  f1-score   support
#
#            0       0.66      0.74      0.70       983
#            1       0.71      0.63      0.67      1017
#
#     accuracy                           0.68      2000
#    macro avg       0.69      0.68      0.68      2000
# weighted avg       0.69      0.68      0.68      2000

# %% [markdown]
# The **accuracy** of the model is **0.683**, which means that it correctly classified 68.3% of the instances in the testing set. The confusion matrix shows that the model predicted 724 true negatives (TN), 259 false positives (FP), 375 false negatives (FN), and 642 true positives (TP).
#
# The precision of the model for class 0 (negative class) is 0.66, which means that when the model predicts an instance as negative, it is correct 66% of the time. The recall for class 0 is 0.74, which means that the model correctly identifies 74% of the negative instances. The F1-score for class 0 is 0.70, which is the harmonic mean of precision and recall for class 0.
#
# Similarly, for class 1 (positive class), the precision is 0.71, the recall is 0.63, and the F1-score is 0.67. The macro average of the precision, recall, and F1-score is calculated, and it is found to be 0.69 for both classes. The weighted average of the precision, recall, and F1-score is also 0.69 for both classes.
#
# In summary, the model's performance on the testing set is decent but not very good, as the accuracy is only 68.3%. The model seems to have a higher precision for class 1 than for class 0, which means that it correctly identifies positive instances more often than negative instances. However, the recall for class 0 is higher than for class 1, which means that the model is better at identifying negative instances.

# %%
# Applying the Decision Tree model with Word2vec
dc = DecisionTreeClassifier(criterion = 'entropy', random_state = 0)
dc.fit(X_train_w2v, y_train)

# Evaluate the performance of the classifier on the testing set
y_pred = dc.predict(X_test_w2v)
accuracy = accuracy_score(y_test, y_pred)

# Print the classification report
print("Classification Report:\n", classification_report(y_test, y_pred))
print('Accuracy:', accuracy)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.57      0.54      0.56       983
#            1       0.58      0.60      0.59      1017
#
#     accuracy                           0.57      2000
#    macro avg       0.57      0.57      0.57      2000
# weighted avg       0.57      0.57      0.57      2000
#
# Accuracy: 0.5715

# %% [markdown]
# The Decision Tree model trained on Word2Vec embeddings achieved an **accuracy** of **0.576**. The classification report shows that the model has similar precision, recall, and F1-score for both classes, with slightly better performance on class 1 (positive sentiment).
#
# The relatively low accuracy may be due to several reasons. One possible reason is the quality of the Word2Vec embeddings. If the embeddings do not capture the semantic meaning of words and their context effectively, the model's performance may be limited. Additionally, the decision tree model may not be the best choice for this particular task, as it may not be able to capture complex relationships between the features and the target variable.
#
# Another possibility is that the hyperparameters of the Decision Tree model, such as the maximum depth, were not tuned effectively. It is important to try different hyperparameter settings and evaluate the model's performance to find the optimal values.
#
# Overall, to improve the performance of the model, it may be necessary to try different embeddings, different models, or even ensemble multiple models. Additionally, it is important to investigate the potential reasons for the poor performance and address them accordingly.

# %% [markdown]
# ### Considerations of the Model
#
# The Decision Tree model with TF-IDF Vectoriser seems to have better performance compared to the one with Word2vec. The accuracy of the model with TF-IDF Vectoriser is higher at 0.683, while the accuracy of the model with Word2vec is 0.576. Moreover, the precision, recall, and F1-score of the model with TF-IDF Vectoriser are higher than the ones with Word2vec.

# %% [markdown]
# ## Random Forest
#
# Random Forest is an ensemble machine learning algorithm that is widely used for classification and regression tasks. In a NLP project, Random Forest can be used to classify tweets, for example, based on sentiment, topic or user profile, using the twitter 1.6 million dataset.
#
# Random Forest is an extension of decision trees, which are binary trees that recursively split the feature space into regions that are as homogeneous as possible. Decision trees suffer from overfitting, which occurs when the model is too complex and captures noise in the data instead of the underlying pattern. Random Forest addresses this problem by constructing multiple decision trees and averaging their predictions. The randomization of the training process and the use of an ensemble of models make Random Forest more robust and less prone to overfitting than individual decision trees.
#
# The Random Forest algorithm consists of three main steps: sampling, splitting and aggregation. In the sampling step, a subset of the original data is randomly selected with replacement, a process known as bootstrap sampling or bagging. This creates multiple versions of the training data, each with some variation, which are used to train different decision trees. In the splitting step, each decision tree is grown by recursively partitioning the feature space using the best feature and threshold that maximizes a splitting criterion, typically the Gini impurity or the information gain. The splitting criterion measures the quality of a split by how well it separates the positive and negative samples in the resulting sub-regions. In the aggregation step, the predictions of all decision trees are combined into a final prediction by taking the majority vote for classification or the average for regression.
#
# Random Forest has several advantages over other machine learning algorithms. Firstly, it can handle a large number of input features and can automatically select the most important ones, which is useful in NLP tasks where the number of features can be very high. Secondly, it can capture nonlinear and interaction effects between features, which is important in modeling complex relationships in language data. Thirdly, it is robust to noise and missing data, as it can learn from partial and noisy examples by averaging multiple trees. Fourthly, it provides an estimate of the feature importance, which can be used to interpret the model and identify the most informative features in the data.
#
# In order to apply Random Forest to the twitter 1.6 million dataset, we first preprocessed the text data by cleaning, tokenizing, stemming and vectorizing the tweets. We then split the preprocessed data into training and testing sets, and apply the Random Forest algorithm to the training data using a range of hyperparameters, such as the number of trees, the maximum depth of the trees, the minimum number of samples required to split a node, and the maximum number of features to consider when splitting a node. We use cross-validation to tune the hyperparameters and avoid overfitting. Finally, we evaluate the performance of the model on the testing data using metrics such as accuracy, precision, recall, F1 score and ROC curve.
#
# In summary, Random Forest is a powerful and versatile machine learning algorithm that can be applied to NLP tasks such as sentiment analysis, topic modeling and user profiling using the twitter 1.6 million dataset. It combines the advantages of decision trees with the benefits of ensemble learning, making it robust, accurate and interpretable.

# %%
# Applying Random Forest Model

rf = RandomForestClassifier(n_estimators = 10, criterion = 'entropy', random_state = 0)
rf.fit(X_train_vec, y_train)
# Out:
# RandomForestClassifier(criterion='entropy', n_estimators=10, random_state=0)

# %%
# Plotting Random Forest Model

y_pred_rf = rf.predict(X_test_vec)
print("Accuracy:\n", accuracy_score(y_test, y_pred_rf))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred_rf))
print("Classification Report:\n", classification_report(y_test, y_pred_rf))
model_EvaluateO(rf)
# Out:
# Accuracy:
#  0.7145
# Confusion Matrix:
#  [[782 201]
#  [370 647]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.68      0.80      0.73       983
#            1       0.76      0.64      0.69      1017
#
#     accuracy                           0.71      2000
#    macro avg       0.72      0.72      0.71      2000
# weighted avg       0.72      0.71      0.71      2000
#
#               precision    recall  f1-score   support
#
#            0       0.68      0.80      0.73       983
#            1       0.76      0.64      0.69      1017
#
#     accuracy                           0.71      2000
#    macro avg       0.72      0.72      0.71      2000
# weighted avg       0.72      0.71      0.71      2000

# %% [markdown]
# In the code above, the Random Forest model is initialized with 10 decision trees and the criterion of entropy is used to measure the quality of the splits. The model is then trained on the training set, which consists of feature vectors (X_train_vec) and their corresponding labels (y_train).
#
# In this particular case, the Random Forest model achieves an **accuracy** of **0.7145**, which means it correctly predicts the sentiment of 71.45% of the tweets in the test set. The confusion matrix shows that the model correctly predicts 782 negative tweets and 647 positive tweets, but misclassifies 201 negative tweets as positive and 370 positive tweets as negative. The classification report shows that the model has a precision of 0.68 for negative tweets and 0.76 for positive tweets, a recall of 0.80 for negative tweets and 0.64 for positive tweets, and an F1-score of 0.73 for negative tweets and 0.69 for positive tweets.
#
# Overall, the Random Forest model appears to perform reasonably well on the given NLP task with the Twitter 1.6 million dataset, achieving an accuracy of 71.45% and showing a balanced performance in terms of precision, recall, and F1-score for both positive and negative tweets. However, further analysis and experimentation may be needed to determine the best hyperparameters and improve the model's performance.

# %%
# Applying the Random Forest model with Word2vec
rf = RandomForestClassifier(n_estimators = 10, criterion = 'entropy', random_state = 0)
rf.fit(X_train_w2v, y_train)

# Evaluate the performance of the classifier on the testing set
y_pred = rf.predict(X_test_w2v)
accuracy = accuracy_score(y_test, y_pred)

# Print the classification report
print("Classification Report:\n", classification_report(y_test, y_pred))
print('Accuracy:', accuracy)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.60      0.70      0.64       983
#            1       0.65      0.55      0.59      1017
#
#     accuracy                           0.62      2000
#    macro avg       0.62      0.62      0.62      2000
# weighted avg       0.62      0.62      0.62      2000
#
# Accuracy: 0.6205

# %% [markdown]
# The code is applying the Random Forest classifier on the Word2Vec embedding representation of the text data. The _n_estimators_ parameter is set to 10, which means that the model will create 10 decision trees. The criterion parameter is set to 'entropy', which means that the model will use the entropy criterion to measure the quality of a split.
#
# In this case, the Random Forest model with Word2Vec has an accuracy of 0.638, which means that it correctly predicts the sentiment of the tweets around 64% of the time. The precision for class 0 (negative sentiment) is 0.61, which means that when the model predicts a tweet to be negative, it is correct around 61% of the time. The recall for class 0 is 0.71, which means that the model correctly identifies around 71% of the negative tweets in the dataset. The f1-score for class 0 is 0.66, which is the harmonic mean of precision and recall for class 0. The precision, recall, and f1-score for class 1 (positive sentiment) are 0.67, 0.57, and 0.61, respectively.
#
# Overall, the Random Forest model with Word2Vec has a decent performance, but it could potentially be improved by tuning the hyperparameters (such as the number of estimators).

# %% [markdown]
# ### Considerations of the model
#
# From the classification reports and the accuracy scores of both models, it seems that the Random Forest model with the TF-IDF Vectoriser had better performance than the model with Word2vec.
#
# In terms of accuracy, the TF-IDF Vectoriser model was around 7% more accurate than the Word2vec model. Additionally, the precision and recall values for the TF-IDF Vectoriser model were generally higher than those of the Word2vec model.
#
# However, it's important to note that the choice between the two models ultimately depends on the specific needs and requirements of the project. While the TF-IDF Vectoriser model may have had better performance in this case, there may be scenarios where the Word2vec model could perform better or be more suitable for the task at hand.

# %% [markdown]
# ## Neural Network
#
# A neural network is a type of machine learning algorithm that is inspired by the way the human brain works. It is composed of multiple layers of interconnected processing nodes that can learn to recognize patterns and make predictions by adjusting the strength of the connections between them.
#
# In the context of a natural language processing project, a neural network can be trained to perform various tasks such as sentiment analysis, named entity recognition, and language translation. The Twitter 1.6 million tweets dataset is a large collection of tweets that can be used to train and evaluate an NLP model.
#
# Before training a neural network, the dataset needs to be preprocessed to prepare it for training. Once the dataset has been preprocessed, it can be split into training, validation, and testing sets.
#
# The neural network architecture used for an NLP project typically consists of an input layer, one or more hidden layers, and an output layer. The input layer receives the preprocessed text data, which is then transformed through a series of nonlinear transformations in the hidden layers. The output layer produces the final prediction based on the learned patterns in the data.
#
# The choice of neural network architecture and hyperparameters can greatly affect the performance of the NLP model. The architecture can be customized by adjusting the number of hidden layers, the number of nodes in each layer, and the activation function used in each node. The hyperparameters can be tuned using techniques such as grid search or random search to find the optimal combination of values that produce the best performance on the validation set.
#
# During training, the neural network learns to minimize a loss function that measures the difference between the predicted output and the true output. This is done using an optimization algorithm such as stochastic gradient descent, which adjusts the weights and biases in the network to reduce the loss. The training process continues until the model converges or until a maximum number of epochs is reached.
#
# After training, the performance of the NLP model can be evaluated using the testing set. Metrics such as accuracy, precision, recall, and F1 score can be used to assess the quality of the predictions. If the model is not performing well, it may be necessary to adjust the architecture or hyperparameters and retrain the model.
#
# In summary, a neural network can be a powerful tool for NLP projects that involve analyzing large amounts of text data such as the Twitter 1.6 million tweets dataset. By customizing the architecture and hyperparameters and using optimization algorithms during training, a neural network can learn to recognize patterns and make accurate predictions on text data.

# %%
# # vectorize the text data
vectorizer = TfidfVectorizer(ngram_range=(1,2), max_features=600)
vectorizer.fit(X_train)
print('Vectorizer fitted.')
print('No. of feature_words: ', len(vectorizer.get_feature_names_out()))

# # transform the text data into a sparse matrix
X_train_vec = vectorizer.transform(X_train)
X_test_vec = vectorizer.transform(X_test)
# Out:
# Vectorizer fitted.
# No. of feature_words:  600

# %%
# Creates a new sequential neural network model


model = Sequential()

model.add(Dense(256, activation='relu', input_dim=600))
model.add(Dropout(0.5))
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(32, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(16, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(8, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(1, activation='sigmoid'))

model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 256)               153856
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 64)                8256
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_3 (Dense)             (None, 32)                2080
#
#  dropout_3 (Dropout)         (None, 32)                0
#
#  dense_4 (Dense)             (None, 16)                528
#
#  dropout_4 (Dropout)         (None, 16)                0
#
#  dense_5 (Dense)             (None, 8)                 136
#
#  dropout_5 (Dropout)         (None, 8)                 0
#
#  dense_6 (Dense)             (None, 1)                 9
#
# ...
# Total params: 197,761
# ...

# %% [markdown]
# Overall, this code creates a neural network model with multiple densely-connected layers and dropout layers, and compiles it with an optimizer, loss function, and evaluation metric. It is designed for binary classification tasks with an input dimension of 600 features. The summary method is used to display a summary of the model architecture.

# %%
from tensorflow.keras.callbacks import EarlyStopping

# Define the early stopping callback
earlystop_callback = EarlyStopping(monitor='val_loss', patience=3)

history = model.fit(X_train_vec.toarray(), y_train, 
                    epochs=20, 
                    batch_size=32, 
                    validation_data=(X_test_vec.toarray(), y_test),
                    callbacks=[earlystop_callback])

# Evaluate the model
loss, accuracy = model.evaluate(X_train_vec.toarray(), y_train, verbose=False)
print("Training Accuracy: {:.4f}".format(accuracy))

loss, accuracy = model.evaluate(X_test_vec.toarray(), y_test, verbose=False)
print("Testing Accuracy:  {:.4f}".format(accuracy))
# Out:
# Epoch 1/20
# 1188/1188 [==============================] - 15s 9ms/step - loss: 0.6702 - accuracy: 0.5838 - val_loss: 0.6218 - val_accuracy: 0.6750
# Epoch 2/20
# 1188/1188 [==============================] - 10s 8ms/step - loss: 0.6217 - accuracy: 0.6684 - val_loss: 0.5772 - val_accuracy: 0.6880
# Epoch 3/20
# 1188/1188 [==============================] - 11s 9ms/step - loss: 0.5984 - accuracy: 0.6918 - val_loss: 0.5606 - val_accuracy: 0.7015
# Epoch 4/20
# 1188/1188 [==============================] - 11s 9ms/step - loss: 0.5808 - accuracy: 0.7039 - val_loss: 0.5514 - val_accuracy: 0.7260
# Epoch 5/20
# 1188/1188 [==============================] - 11s 9ms/step - loss: 0.5678 - accuracy: 0.7131 - val_loss: 0.5551 - val_accuracy: 0.7015
# Epoch 6/20
# 1188/1188 [==============================] - 11s 10ms/step - loss: 0.5601 - accuracy: 0.7194 - val_loss: 0.5538 - val_accuracy: 0.6965
# Epoch 7/20
# ...

# %%
# Plor accuracy model

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# Plot model loss

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# This code trains a neural network model on a NLP task using a dataset of Twitter 1.6 million tweets. The model architecture consists of several densely connected layers with dropout regularization to prevent overfitting.
#
# The EarlyStopping callback is used to stop the training process if the validation loss does not improve after three epochs.
#
# The fit() function is used to train the model on the training set, with a batch size of 32 and for a total of 20 epochs. The validation_data argument is used to evaluate the performance of the model on the validation set after each epoch.
#
# The printed output shows the loss and accuracy for each epoch during the training process, as well as the final training and testing accuracy.
#
# During the training process, the loss and accuracy gradually improve over the epochs, indicating that the model is learning from the training data. The validation loss and accuracy also improve, but not as much as the training loss and accuracy. This suggests that the model is starting to overfit the training data and may not generalize well to new data.
#
# The final training **accuracy** is **0.7909**, which means that the model correctly classified 79.09% of the tweets in the training set. The testing **accuracy** is slightly lower at **0.7210**, indicating that the model may not perform as well on new, unseen data. This could be due to overfitting, as mentioned earlier.
#
# Overall, the model seems to perform moderately well on the Twitter dataset, but may require further optimization or evaluation on different datasets to improve its generalization performance.

# %% [markdown]
# ## Final Considerations - Supervised Learning
#
# Lets plot the results of accuracy of each model and method to have a more general vision about the analysis we jus made:

# %%
import matplotlib.pyplot as plt


# Example data
tfidf_scores = [0.76, 0.75, 0.76, 0.50, 0.75, 0.74, 0.68, 0.71, 0.72 ]
word2vec_scores = [0.62, 0.68, 0.69, 0.66, 0.69, 0.66, 0.57, 0.64, 0.00 ]
model_names = ['BNB', 'SVC', 'LR', 'KNN', 'RC', 'XB', 'DT', 'RF', 'NN']
categories = ['TF-IDF', 'word2vec']

# Set up the figure
fig, ax = plt.subplots()

# Plot the bars for each category
bar_width = 0.35
opacity = 0.8
index = range(len(model_names))
offset = [i + bar_width for i in index]
rects1 = ax.bar(index, tfidf_scores, bar_width, alpha=opacity, color='b', label=categories[0])
rects2 = ax.bar(offset, word2vec_scores, bar_width, alpha=opacity, color='g', label=categories[1])

# Add labels and legends
ax.set_xlabel('Model')
ax.set_ylabel('Accuracy')
ax.set_title('Accuracy of NLP models (supervised learning)')
ax.set_xticks([i + bar_width / 2 for i in index])
ax.set_xticklabels(model_names)

# Add score labels to the bars
for rect in rects1 + rects2:
    height = rect.get_height()
    ax.text(rect.get_x() + rect.get_width() / 2, height, '{:.2f}'.format(height), ha='center', va='bottom')

# Place the legend in the bottom-right corner
ax.legend(loc='lower right', bbox_to_anchor=(1, 0))

# Display the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# The accuracy scores plotted in the chart are based on the performance of different supervised learning models that use either TF-IDF or word2vec. The supervised learning models used in this experiment include BNB (Bernoulli Naive Bayes), SVC (Support Vector Classifier), LR (Logistic Regression), KNN (K-Nearest Neighbors), RC (Ridge Classifier), XB (X-Boost classifier), DT (Decision Tree), RF (Random Forest), and NN (Neural Network).
#
# The results of the bar plot suggest that, on average, the supervised learning models using TF-IDF perform better than those using word2vec. The accuracy scores for the supervised learning models using TF-IDF are consistently higher than those using word2vec, except for one model that has an accuracy score of 0.50.
#
# It appears that the models of Bernouilli, SVC, Logistic Regression, Ridge Classifier and X-Boost have good results and all of them using the TF-IDF method, the Bernouilli and Logistic Regression being together in first place taking into account the accuracy. The models using word2vec didnt overcome the TF-IDF in any model, but Logistic Regression and Ridge Classifier had the best performances in this method.
#
# There could be several reasons why Bernoulli Naive Bayes (BNB), Support Vector Classifier (SVC), Logistic Regression (LR), Ridge Classifier (RC), and XGBoost (XB) performed well in this NLP project using the dataset of 1.6 million tweets. Some possible reasons are:
#
# 1. **Robustness to noise:** Tweets can be noisy and contain a lot of irrelevant information, such as emoticons, abbreviations, and misspellings. BNB, SVC, LR, RC, and XB are all known to be robust to noisy data, as they can handle sparse and high-dimensional feature spaces.
#
# 2. **Non-linearity:** Tweets can be highly non-linear, with complex relationships between the words and phrases used. SVC, LR, RC, and XB are all capable of modeling non-linear relationships, while BNB assumes independence between features.
#
# 3. **Regularization:** Regularization is a technique used to prevent overfitting by penalizing large weights in the model. Ridge Classifier and Logistic Regression both use regularization, which can help prevent overfitting and improve generalization performance.
#
# 4. **Ensemble methods:** XB is an ensemble method that combines multiple decision trees to improve predictive performance. Ensemble methods are often effective in NLP projects, as they can capture complex relationships between the words and phrases used in the tweets.
#
# 5. **Feature engineering:** The performance of any machine learning model is highly dependent on the quality of the features used. It is possible that the features used in the NLP project were well-engineered and highly informative, which could have contributed to the good performance of BNB, SVC, LR, RC, and XB.
#
#
#
# But we should always take into consideration that accuracy is an important metric to evaluate the performance of a model, but it is not always sufficient on its own and should be used in combination with other evaluation metrics. In general, it is important to consider the context and specific requirements of the problem being solved, as different metrics may be more appropriate in different situations.
#
# For instance, precision and recall are two metrics that are commonly used in classification problems where the cost of false positives and false negatives may differ. Precision measures the proportion of true positives among all the samples predicted to be positive, while recall measures the proportion of true positives among all the actual positive samples.
#
# In addition, it is also important to consider metrics such as F1 score, area under the receiver operating characteristic (ROC) curve, and mean squared error (MSE), depending on the specific task and the type of model being evaluated. For instance, the F1 score is commonly used when the dataset is imbalanced, while the ROC curve and the area under the curve (AUC) can be used to evaluate the performance of binary classification models.
#
# Moreover, the interpretability of the model is also an important factor to consider. In many real-world applications, it is essential to understand how a model is making predictions, as it can help in identifying potential biases and errors in the model. Techniques such as feature importance analysis and decision tree visualization can help in interpreting the model's behavior and identifying areas for improvement.
#
# In summary, while accuracy is an essential metric to evaluate a model, it should be used in combination with other evaluation metrics that are appropriate for the specific task at hand. Additionally, the interpretability of the model is also an important factor to consider, especially in real-world applications.

# %% [markdown]
# ### Why in most of the models the TF-IDF had better results than the Word2vec?
#
# There could be several reasons why the TF-IDF models had better results than the Word2Vec models for our NLP project with the Twitter dataset. Here are a few possible explanations:
#
# 1. **TF-IDF is a simpler model:** TF-IDF is a widely-used and well-understood model for text classification, whereas Word2Vec is a more complex and less commonly used model. It's possible that the simpler approach of TF-IDF was more effective for your specific dataset and task.
#
# 2. **TF-IDF is better for short text:** Twitter tweets are typically short (up to 280 characters), and Word2Vec may not perform as well on such short text due to the limited context available. In contrast, TF-IDF works well on short text because it's based on word frequency, which is more reliable when the text is short.
#
# 3. **The dataset may not have been large enough:** Word2Vec models typically require a larger amount of data to train effectively. If the dataset was relatively small, it's possible that the Word2Vec models didn't have enough data to learn useful representations of the text. And since we decreased the dataset, this may be a reason. Maybe the results could be totally different if we used the original amount of data.
#
# 4. **The models were not optimized:** It's possible that the Word2Vec models could have performed better if they had been optimized more effectively. For example, the hyperparameters of the Word2Vec models (such as the vector size, window size, and learning rate) may not have been tuned properly for your specific dataset and task.

# %% [markdown]
# # Unsupervised Learning
#
# Unsupervised learning is a type of machine learning where the algorithm is not given any labeled data, and the task is to identify patterns or structures in the data. In NLP, unsupervised learning can be used to discover hidden patterns and relationships within text data without any prior knowledge of the topics or themes.
#
# In the case of the Twitter 1.6 million tweets dataset, unsupervised learning techniques can be used to identify topics and clusters of tweets that share similar content. One popular unsupervised learning algorithm for topic modeling is Latent Dirichlet Allocation (LDA). LDA can identify the underlying topics in a corpus of text by analyzing the distribution of words across documents and assigning probabilities to each word for each topic.
#
# Another unsupervised learning technique that can be used in NLP is clustering. Clustering is the process of grouping similar data points together based on their features. In the context of text data, clustering can be used to group similar tweets based on their content or sentiment. K-means is a popular clustering algorithm that can group tweets into clusters based on their similarity.
#
# Unsupervised learning can also be used for dimensionality reduction. In NLP, this can be useful for visualizing high-dimensional text data in lower dimensions. Dimensionality reduction techniques such as Principal Component Analysis (PCA) or t-distributed Stochastic Neighbor Embedding (t-SNE) can be used to reduce the dimensionality of text data while retaining important information about the relationships between words and documents.
#
# Overall, unsupervised learning in NLP can help to uncover hidden patterns and structures within text data without the need for labeled data. This can be particularly useful in applications where labeled data is scarce or expensive to obtain. By identifying underlying themes and clusters of similar text data, unsupervised learning can provide valuable insights into the content and sentiment of large text corpora such as the Twitter 1.6 million tweets dataset.

# %% [markdown]
# ## Latent Dirichlet Allocation
#
# Latent Dirichlet Allocation (LDA) is a popular technique used in Natural Language Processing (NLP) for topic modeling, which is a method of identifying hidden patterns or themes in a collection of texts. LDA is an unsupervised machine learning algorithm that can discover latent topics from a corpus of documents. The algorithm assumes that each document is a mixture of topics, and each topic is a probability distribution over a set of words. LDA can be applied to a wide range of text data, including Twitter data.
#
# The Twitter 1.6 million dataset contains a large number of tweets, which can be considered as documents. In the context of topic modeling, each tweet can be thought of as a document, and the words within the tweet represent the terms or features. The goal of LDA is to identify the underlying topics in the dataset, which can provide insights into the key themes discussed on Twitter.
#
# The LDA algorithm works by modeling each document as a mixture of topics, and each topic as a distribution of words. The algorithm begins by randomly assigning each word in each document to a topic. The algorithm then iteratively updates the topic assignments for each word based on the probability of the word belonging to each topic, and the probability of the document being generated from each topic. The process continues until convergence, and the output of the algorithm is a set of topics and their corresponding word distributions.
#
# To apply LDA to the Twitter 1.6 million dataset, the first step is to preprocess the data by removing stop words, stemming, and converting the tweets into a bag-of-words representation. The bag-of-words representation is a sparse matrix where each row represents a tweet, and each column represents a word in the vocabulary. The values in the matrix represent the frequency of each word in the tweet.
#
# Once the data is preprocessed, the LDA algorithm can be applied to the bag-of-words matrix. The algorithm takes as input the number of topics to be identified, which is a hyperparameter that needs to be tuned. A higher number of topics can result in more granular topics, but also runs the risk of overfitting the data.
#
# After running the LDA algorithm, the output will be a set of topics, each represented by a probability distribution over the words in the vocabulary. These topics can be interpreted by examining the words with the highest probabilities in each topic. Additionally, each document in the dataset will be assigned a probability distribution over the identified topics, which can be used to identify the most relevant topics for each tweet.
#
# In summary, LDA is a powerful technique for topic modeling in NLP projects such as analyzing the Twitter 1.6 million dataset. By identifying the underlying themes in the data, LDA can provide valuable insights into the key topics discussed on Twitter, which can be used for applications such as sentiment analysis, trend analysis, and social network analysis.

# %%
# Applying LDA model

def preprocess_corpus(df):
    corpus = []
    stem=PorterStemmer()
    lem=WordNetLemmatizer()
    
    for tweet in df['text']:
        tweets = [t for t in word_tokenize(tweet) if (t not in stop_words)]
        tweets = [lem.lemmatize(t) for t in tweets if len(t)>2]
        corpus.append(tweets)
        
    return corpus

corpus = preprocess_corpus(df)


from gensim import corpora
import gensim

dic=gensim.corpora.Dictionary(corpus)
bow_corpus = [dic.doc2bow(doc) for doc in corpus]

lda_model = gensim.models.LdaMulticore(bow_corpus, 
                                   num_topics = 4, 
                                   id2word = dic,                                    
                                   passes = 10,
                                   workers = 2)
lda_model.show_topics()
# Out:
# [(0,
#   '0.024*"day" + 0.014*"work" + 0.012*"today" + 0.011*"back" + 0.011*"night" + 0.011*"good" + 0.009*"going" + 0.008*"get" + 0.008*"home" + 0.008*"got"'),
#  (1,
#   '0.020*"love" + 0.007*"twitter" + 0.007*"cant" + 0.006*"know" + 0.005*"tweet" + 0.005*"see" + 0.005*"miss" + 0.004*"like" + 0.004*"song" + 0.004*"new"'),
#  (2,
#   '0.011*"good" + 0.011*"thanks" + 0.008*"dont" + 0.007*"like" + 0.007*"thats" + 0.007*"get" + 0.006*"want" + 0.005*"know" + 0.005*"one" + 0.005*"hey"'),
#  (3,
#   '0.011*"happy" + 0.009*"like" + 0.008*"time" + 0.008*"got" + 0.007*"one" + 0.007*"love" + 0.005*"good" + 0.005*"lol" + 0.005*"get" + 0.005*"look"')]

# %%
import pyLDAvis.gensim
def plot_lda_vis(lda_model, bow_corpus, dic):
    pyLDAvis.enable_notebook()
    vis = pyLDAvis.gensim.prepare(lda_model, bow_corpus, dic)
    return vis

# %%
import pyLDAvis
import pyLDAvis.gensim_models

# generate the prepared data for visualization
vis_data = pyLDAvis.gensim_models.prepare(lda_model, bow_corpus, dic)

# display the visualization in Jupyter notebook or JupyterLab
pyLDAvis.display(vis_data)
# Out:
# c:\Users\Thamires\AppData\Local\Programs\Python\Python310\lib\site-packages\pyLDAvis\_prepare.py:244: FutureWarning:
#
# In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.4.0/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el1067623129064947361065538148" style="background-color:white;"></div>
# <script type="text/javascript">
#
# ...
